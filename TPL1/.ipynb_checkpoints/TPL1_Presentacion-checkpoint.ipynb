# %% [markdown]
# <img src="./TPL1_Logo_UTN.svg" align="right" width="150" />
#
# ##
#
# ***
#
# ## (950431) Teoría de Circuitos II
#
# ***
#
# #### Profesor: Mariano Llamedo Soria  <llamedom@frba.utn.edu.ar>
# #### Jefe de TPs: César Fuoco  <cfuoco@frba.utn.edu.ar>
# #### Ayudante de TPs: Israel Pavelek <pavel@frba.utn.edu.ar>
#
# ####
# ***

# %% [markdown]
# # Trabajo Práctico de Laboratorio # 1
#
# #### Autores: *Celada, Matías Iván* <mcelada@frba.utn.edu.ar>
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;*Gerez, Víctor Rodolfo* <victorgerez@frba.utn.edu.ar>
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;*Moharos, David Santiago* <dmoharos@frba.utn.edu.ar>
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;*Niño, Jorge Andrés* <jnino@frba.utn.edu.ar>
#
# ####
#
# ***

# %% [markdown]
# <img src="./TPL1_Plantilla_Filtro_HP.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# \begin{equation}
# α_{min}= 1 dB
# \end{equation}
#
# \begin{equation}
# α_{max}= 20 dB
# \end{equation}
#
# \begin{equation}
# f_s= 1200 Hz
# \end{equation}
#
# \begin{equation}
# f_p= 4600 Hz
# \end{equation}

# %% [markdown]
# \begin{equation}
# ω_s= 2*π*1200 \frac{rad}{s}
# \end{equation}
#
# \begin{equation}
# ω_p= 2*π*4600 \frac{rad}{s}
# \end{equation}
#
# \begin{equation}
# Ω_ω= ω_p= 2*π*4600 \frac{rad}{s}
# \end{equation}
#
# \begin{equation}
# ω_{sn}= \frac{ω_s}{Ω_ω}= \frac{ω_s}{ω_p}= \frac{2*π*1200 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 0,2609
# \end{equation}
#
# \begin{equation}
# ω_{pn}= \frac{ω_p}{Ω_ω}= \frac{ω_p}{ω_p}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 1
# \end{equation}

# %% [markdown]
# <img src="./TPL1_Plantilla_Filtro_LP.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# \begin{equation}
# Ω=\frac{1}{ω}
# \end{equation}
#
# \begin{equation}
# Ω_{sn}= \frac{1}{ω_{sn}}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*1200 [\frac{rad}{s}]}= 3,8333
# \end{equation}
#
# \begin{equation}
# Ω_{pn}= \frac{1}{ω_{pn}}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 1
# \end{equation}

# %% [markdown]
# \begin{equation}
# |T(jΩ)|^2= T(jΩ)*T(-jΩ)= {T(s)*T(-s)}|_{s= jΩ}= \frac{1}{1+ε^2*C_n^2(Ω)}
# \end{equation}
#
# \begin{equation}
# |α|^2= 1+ε^2*C_n^2(Ω)
# \end{equation}
#
# \begin{equation}
# |α|_{dB} \triangleq α_{dB}
# \end{equation}
#
# \begin{equation}
# α_{dB}= 10*log[1+ε^2*C_n^2(Ω)]
# \end{equation}
#
# \begin{equation}
# ε^2= \frac{10^{\frac{α_{max}}{10}}-1}{C_n^2(Ω)}
# \end{equation}
#
# \begin{equation}
# (α_{max}, Ω_{pn}): ε^2= \frac{10^{\frac{α_{max}}{10}}-1}{C_n^2(Ω_{pn})}= \frac{10^{\frac{20}{10}}-1}{1}= 0,2589
# \end{equation}
#
# \begin{equation}
# ε= 0,5088
# \end{equation}
#
# \begin{equation}
# (α_{min}, Ω_{sn}): α_{min} = 10*log[1 + ε^2*C_n^2(Ω_{sn})]
# \end{equation}
#
# \begin{equation}
# N= 1: ¿att = 6.8167 dB \geq α_{min}= 20?
# \end{equation}
#
# \begin{equation}
# N= 2: ¿att = 23.2155 dB \geq α_{min}= 20?
# \end{equation}
#
# \begin{equation}
# N= 2
# \end{equation}
#
# \begin{equation}
# C_n^2= cosh^2(N*cosh^{-1}(Ω_{sn}))
# \end{equation}
#
# \begin{equation}
# C_0(Ω)= 1
# \end{equation}
#
# \begin{equation}
# C_1(Ω)= Ω
# \end{equation}
#
# \begin{equation}
# C_n(Ω)= 2*Ω*C_{n-1}(Ω) - C_{n-2}(Ω)
# \end{equation}
#
# \begin{equation}
# C_2(Ω)= 2*Ω*Ω - 1= 2*Ω^2-1
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*C_n^2(Ω)}= \frac{1}{1+ε^2*C_2^2(Ω)}= \frac{1}{1+ε^2*(2*Ω^2-1)^2}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*(2*Ω^2-1)^2}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*(2*Ω^2-1)*(2*Ω^2-1)}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*(4*Ω^4-2*Ω^2-2*Ω^2+1)}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*(4*Ω^4-4*Ω^2+1)}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{1}{1+ε^2*[4*(\frac{$}{j})^4-4*(\frac{$}{j})^2+1]}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{1}{1+ε^2*[4*$^4+4*$^2+1]}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{1}{1+4*ε^2*^$4+4*ε^2*$^2+ε^2}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{1}{4*ε^2*$^4+4*ε^2*$^2+ε^2+1}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{\frac{1}{4*ε^2}}{\frac{4*ε^2*$^4+4*ε^2*$^2+ε^2+1}{4*ε^2}}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{\frac{1}{4*ε^2}}{$^4+$^2+\frac{ε^2+1}{4*ε^2}}
# \end{equation}
#
# \begin{equation}
# a= \frac{1}{4*ε^2}
# \end{equation}
#
# \begin{equation}
# b= \frac{ε^2+1}{4*ε^2}= \frac{ε^2}{4*ε^2} + \frac{1}{4*ε^2}= \frac{1}{4} + \frac{1}{4*ε^2}= \frac{1}{4} + a
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{a}{$^4+$^2+b}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{α}{$^2 + β*$ + γ}*\frac{α}{$^2 - β*$ + γ}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{α^2}{$^4 -β*$^3 +γ*$^2 +β*$^3 -β^2*$^2 +β*γ*$ +γ*$^2 -β*γ*$ +γ^2}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{α^2}{$^4 +(-β+β)*$^3 +(2*γ-β^2)*$^2 +(β*γ-β*γ)*$ +γ^2}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{α^2}{$^4 +(2*γ-β^2)*$^2 +γ^2}
# \end{equation}
#
# \begin{equation}
# α^2= a= \frac{1}{4*ε^2}
# \end{equation}
#
# \begin{equation}
# α= \sqrt{\frac{1}{4*ε^2}}= \frac{1}{2*ε}= \frac{1}{2*0,5088}= 0.9827
# \end{equation}
#
# \begin{equation}
# 2*γ-β^2= 1
# \end{equation}
#
# \begin{equation}
# β= \sqrt{2*γ-1}
# \end{equation}
#
# \begin{equation}
# γ^2= b
# \end{equation}
#
# \begin{equation}
# γ^2= \frac{1}{4} + a
# \end{equation}
#
# \begin{equation}
# γ= \sqrt{\frac{1}{4} + a}= \sqrt{\frac{1}{4} + α^2}= \sqrt{\frac{1}{4} + 0.9827^2}= 1,1026
# \end{equation}
#
# \begin{equation}
# β= \sqrt{2*γ-1}= \sqrt{2*1,1026-1}= 1,0978
# \end{equation}
#
# \begin{equation}
# T($)= \frac{0.9827}{$^2 + 1,0978*$ + 1,1026}
# \end{equation}
#
# \begin{equation}
# $= \frac{1}{s}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{0.9827}{(\frac{1}{s})^2 + 1,0978*(\frac{1}{s}) + 1,1026}= \frac{0.9827}{\frac{1}{s^2} + \frac{1,0978}{s} + 1,1026}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{0.9827}{\frac{1 +1,0978*s +1,1026*s^2}{s^2}}= = \frac{0.9827*s^2}{1 +1,0978*s +1,1026*s^2}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{\frac{0.9827}{1,1026}*s^2}{\frac{1 +1,0978*s +1,1026*s^2}{1,1026}}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac {\frac{0.9827}{1,1026}*s^2} {\frac{1}{1,1026} +\frac{1,0978}{1,1026}*s +\frac{1,1026}{1,1026}*s^2}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac {0,8916*s^2} {0,9069 +0,9956*s + s^2}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac {0,8916*s^2} {s^2 +0,9956*s +0,9069}
# \end{equation}

# %% [markdown]
# <img src="TPL1_Logo_UTN.svg" align="right" width="150" />
#
# ##
#
# ***
#
# ## (950431) Teoría de Circuitos II
#
# ***
#
# #### Profesor: Mariano Llamedo Soria  <llamedom@frba.utn.edu.ar>
# #### Jefe de TPs: César Fuoco  <cfuoco@frba.utn.edu.ar>
# #### Ayudante de TPs: Israel Pavelek <pavel@frba.utn.edu.ar>

# %% [markdown]
# ***
# ***
#
# ####
#
# ## Trabajo Práctico de Laboratorio # 1: Teoría Moderna y Filtrado Activo
#
# ####
#
# ***
# ***
#
# ### <span style="text-decoration: underline;">Autor</span>
# #### *Moharos, David Santiago* <dmoharos@frba.utn.edu.ar>
#
# ####
#
# ***
#
# ### <span style="text-decoration: underline;">Integrantes grupo # 1</span>
# ##### *Celada, Matías Iván*
# ##### *Gerez, Victor Rodolfo*
# ##### *Moharos, David Santiago*
# ##### *Niño, Jorge Andrés*
#
# ####
#
# ***

# %% [markdown]
# ### <span style="text-decoration: underline;">Indice</span>
#
# #####
#
# ##### 1. [Introducción](#introduccion)
# ##### 2. [Objetivos](#objetivos)
# ##### 3. [Descripción](#descripcion)
# ##### 4. [Análisis](#analisis)
# ##### 5. [Simulación numérica](#simulacion_numerica)
# ##### 6. [Simulación circuital](#simulacion_circuital)
# ##### 7. [Referencias](#referencias)
#
# ####
#
# ***

# %% [markdown]
# #####
# <a id="introduccion"></a>
# ### <span style="text-decoration: underline;">Introducción</span>
# #####
#
# ##### El trabajo práctico implica la implementación de una función transferencia con el circuito integrado [UAF42](https://www.ti.com/lit/ds/symlink/uaf42.pdf?ts=1653513515595&ref_url=https%253A%252F%252Fwww.ti.com%252Fproduct%252FUAF42%253Futm_source%253Dsupplyframe%2526utm_medium%253DSEP%2526utm_campaign%253Dnot_alldatasheet%2526DCM%253Dyes%2526dclid%253DCOTE4LXH-_cCFaCFlQIdQoELbA) que posee una característica especial: capacitores integrados de muy baja tolerancia, aproximadamente del 1%. Esto permite obtener respuestas en frecuencia del filtro sumamente similares a las simulaciones.
#
# ##### A continuación se parte el diseño en 3 secciones de forma tal de tener instancias intermedias para consultar a los docentes sobre cuestiones de implementación y armado.
#
# #####
#
# ***

# %% [markdown]
# #####
# <a id="objetivos"></a>
# ### <span style="text-decoration: underline;">Objetivos</span>
# #####
#
# ##### > Consolidar los conceptos de teoría moderna mediante la implementación circuital.
# ##### > Simular e implementar el filtro con componentes activos de precisión.
# ##### > Medir las partes de la función transferencia para frecuencias menores a 100 kHz.
#
# #####
#
# ***

# %% [markdown]
# #####
# <a id="descripcion"></a>
# ### <span style="text-decoration: underline;">Descripción</span>
# #####
#
# ##### El trabajo práctico consiste en el diseño, análisis, medición y discusión de un filtro activo.
#
# #####
#
# <img src="TPL1_Plantilla_Filtro_HP_Datos.png" style="margin-left:auto; margin-right:auto"/>
#
# #####
#
# ***
# ***

# %% [markdown]
# #####
# <a id="analisis"></a>
# ### <span style="text-decoration: underline;">Análisis:</span>
# #####
#
# ##### > Obtenga el orden del filtro y el ε.
# ##### > Obtenga la función transferencia en el dominio de Laplace. Identifique polos y ceros.
# ##### > Sintetice los valores de los componentes externos del circuito UAF42.
#
# #####
#
# ***

# %% [markdown]
# #### <span style="text-decoration: underline;">Datos de plantilla filtro pasa altos objetivo</span>
#
# ####
#
# <img src="TPL1_Plantilla_Filtro_HP_Grafica.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# #####
#
# \begin{equation}
# α_{máx}= 1 dB
# \end{equation}
#
# \begin{equation}
# α_{mín}= 20 dB
# \end{equation}
#
# \begin{equation}
# f_s= 1200 Hz
# \end{equation}
#
# \begin{equation}
# f_p= 4600 Hz
# \end{equation}

# %% [markdown]
# #####
# #### <span style="text-decoration: underline;">Normalización de plantilla filtro pasa altos objetivo:</span>
# #####
#
# \begin{equation}
# ω_s= 2*π*1200 \frac{rad}{s}
# \end{equation}
#
# \begin{equation}
# ω_p= 2*π*4600 \frac{rad}{s}
# \end{equation}
#
# \begin{equation}
# Ω_ω= ω_p= 2*π*4600 \frac{rad}{s}
# \end{equation}
#
# \begin{equation}
# ω_{s_n}= \frac{ω_s}{Ω_ω}= \frac{ω_s}{ω_p}= \frac{2*π*1200 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 0,2609
# \end{equation}
#
# \begin{equation}
# ω_{p_n}= \frac{ω_p}{Ω_ω}= \frac{ω_p}{ω_p}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 1
# \end{equation}
#
# ####
#
# ***

# %% [markdown]
# #### <span style="text-decoration: underline;">Datos de plantilla filtro pasa bajos prototipo</span>
#
# ####
#
# <img src="TPL1_Plantilla_Filtro_LP.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# #####
# #### <span style="text-decoration: underline;">Núcleo de la transformación:</span> $\begin{equation} Ω=\frac{1}{ω} \end{equation}$
# #####
#
# \begin{equation}
# Ω_{s_n}= \frac{1}{ω_{s_n}}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*1200 [\frac{rad}{s}]}= 3,8333
# \end{equation}
#
# \begin{equation}
# Ω_{p_n}= \frac{1}{ω_{p_n}}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 1
# \end{equation}
#
# #####
#
# ***

# %% [markdown]
# #### <span style="text-decoration: underline;">Cálculo del grado de libertad de la función $ε$ y el orden del filtro N</span>
#
# #####
# ##### Tomando como referencias las ecuaciones de $|T(jω)|^2$ en su aproximación de Chevyshev [$^{(1)}$](#1) [$^{(2)}$](#2):
# #####
#
# \begin{equation}
# |T(jΩ)|^2= T(jΩ)*T(-jΩ)= {T(s)*T(-s)}|_{s= jΩ}= \frac{1}{1+ε^2*C_n^2(Ω)}
# \end{equation}
#
# #####
# ##### Podemos entonces establecer la atenuación en función de la ecuación anterior como la inversa de $|T(jΩ)|^2$:
# #####
#
# \begin{equation}
# |α|^2= \frac {1}{|T(jΩ)|^2}= \frac{1}{\frac{1}{1+ε^2*C_n^2(Ω)}}= 1+ε^2*C_n^2(Ω)
# \end{equation}
#
# #####
# ##### Considerando que $|α|_{dB} \triangleq α_{dB}$, podemos expresar la ecuación en dB [$^{(3)}$](#3):
# #####
#
# \begin{equation}
# α_{dB}= 10*log[1+ε^2*C_n^2(Ω)]
# \end{equation}
#
# #####
# ##### Despejando $ε^2$ de la ecuación anterior, obtenemos [$^{(4)}$](#4):
# #####
#
# \begin{equation}
# ε^2= \frac{10^{\frac{α_{máx}}{10}}-1}{C_n^2(Ω)}
# \end{equation}
#
# #####
# ##### Considerando la máxima atenuación requerida por la plantilla $α_{máx}$ en el vértice de fin de la banda de paso $Ω_{p_n}$, obtenemos $ε^2$:
# #####
#
# \begin{equation}
# ε^2= \frac{10^{\frac{α_{máx}}{10}}-1}{C_n^2(Ω_{p_n})}= \frac{10^{\frac{20}{10}}-1}{1}
# \end{equation}
#
# \begin{equation}
# \boxed{ε^2= 0,2589}
# \end{equation}
#
# \begin{equation}
# \boxed{ε= 0,5088}
# \end{equation}
#
# #####
# ##### Considerando la mínima atenuación requerida por la plantilla $α_{mín}$ en el vértice del inicio de la banda de detenida $Ω_{s_n}$, iteramos N de forma tal que la atenuación sea mayor o igual a obtenemos $α_{mín}$:
# #####
#
# \begin{equation}
# α_{mín} = 10*log[1 + ε^2*C_n^2(Ω_{s_n})]
# \end{equation}
#
# \begin{equation}
# N= 1: ¿α(Ω_{s_n}) = 6.8167 dB \geq α_{mín}= 20 dB? \rightarrow No...
# \end{equation}
#
# \begin{equation}
# N= 2: ¿α(Ω_{s_n}) = 23.2155 dB \geq α_{mín}= 20 dB? \rightarrow ¡Sí!
# \end{equation}
#
# \begin{equation}
# \boxed{N= 2}
# \end{equation}
#
# #####
#
# ***
#
# #####
# #### <span style="text-decoration: underline;">Cálculo de la función transferencia $T_{HP}(s)$</span>
# #####
#
# ##### Recordando que $|T(jΩ)|^2= T(jΩ)*T(-jΩ)= {T(s)*T(-s)}|_{s= jΩ}= \frac{1}{1+ε^2*C_n^2(Ω)}$ y habiendo obtenido $ε^2$ y N, procedemos a calcular los polinomios de orden N de Chevyshev definidos como:
# #####
#
# \begin{equation}
# C_n^2= cosh^2(n*cosh^{-1}(Ω_{s}))
# \end{equation}
#
# #####
# ##### Utilizando identidades trigonómetricas [$^{(5)}$](#5), calculamos el polinomio para el grado N obtenido:
# #####
#
# \begin{equation}
# C_0(Ω)= 1
# \end{equation}
#
# \begin{equation}
# C_1(Ω)= Ω
# \end{equation}
#
# \begin{equation}
# C_n(Ω)= 2*Ω*C_{n-1}(Ω) - C_{n-2}(Ω)
# \end{equation}
#
# \begin{equation}
# C_2(Ω)= 2*Ω*Ω - 1= 2*Ω^2-1
# \end{equation}
#
# #####
# ##### Reemplazando el polinomio de grado 2 en la ecuación de $|T(jΩ)|^2= \frac{1}{1+ε^2*C_n^2(Ω)}$, operamos algebraicamente:
# #####
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*C_n^2(Ω)}= \frac{1}{1+ε^2*C_2^2(Ω)}= \frac{1}{1+ε^2*(2*Ω^2-1)^2}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*(2*Ω^2-1)^2}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*(2*Ω^2-1)*(2*Ω^2-1)}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*(4*Ω^4-2*Ω^2-2*Ω^2+1)}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{$}{j}}= \frac{1}{1+ε^2*(4*Ω^4-4*Ω^2+1)}
# \end{equation}
#
# #####
# ##### Reemplazando $Ω$ por $\frac{$}{j}$, obtenemos:
# #####
#
# \begin{equation}
# T($)*T(-$)= \frac{1}{1+ε^2*\left[4*(\frac{$}{j})^4-4*(\frac{$}{j})^2+1\right]}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{1}{1+ε^2*\left[4*$^4+4*$^2+1\right]}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{1}{1+4*ε^2*^$4+4*ε^2*$^2+ε^2}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{1}{4*ε^2*$^4+4*ε^2*$^2+ε^2+1}
# \end{equation}
#
# #####
# ##### Dejamos mónico el polinomio denominador:
# #####
#
# \begin{equation}
# T($)*T(-$)= \frac{\frac{1}{4*ε^2}}{\frac{4*ε^2*$^4+4*ε^2*$^2+ε^2+1}{4*ε^2}}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{\frac{1}{4*ε^2}}{$^4+$^2+\frac{ε^2+1}{4*ε^2}}
# \end{equation}
#
# #####
# ##### Definimos los siguientes coeficientes:
# #####
#
# \begin{equation}
# a= \frac{1}{4*ε^2}
# \end{equation}
#
# \begin{equation}
# b= \frac{ε^2+1}{4*ε^2}= \frac{ε^2}{4*ε^2} + \frac{1}{4*ε^2}= \frac{1}{4} + \frac{1}{4*ε^2}= \frac{1}{4} + a
# \end{equation}
#
# #####
# ##### Llegamos a la siguiente expresión en términos de los coeficientes a y b:
# #####
#
# \begin{equation}
# T($)*T(-$)= \frac{a}{$^4+$^2+b}
# \end{equation}
#
# #####
# ##### Expresamos ahora de forma general en secciones de segundo orden:
# #####
#
# \begin{equation}
# T($)*T(-$)= \frac{α}{$^2 + β*$ + γ}*\frac{α}{$^2 - β*$ + γ}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{α^2}{$^4 -β*$^3 +γ*$^2 +β*$^3 -β^2*$^2 +β*γ*$ +γ*$^2 -β*γ*$ +γ^2}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{α^2}{$^4 +(-β+β)*$^3 +(2*γ-β^2)*$^2 +(β*γ-β*γ)*$ +γ^2}
# \end{equation}
#
# \begin{equation}
# T($)*T(-$)= \frac{α^2}{$^4 +(2*γ-β^2)*$^2 +γ^2}
# \end{equation}
#
# ######
# ##### Igualamos los coeficientes de ambas expresiones y resolvemos el sistema de ecuaciones:
# #####
#
# \begin{equation}
# α^2= a= \frac{1}{4*ε^2}
# \end{equation}
#
# \begin{equation}
# α= \sqrt{\frac{1}{4*ε^2}}= \frac{1}{2*ε}= \frac{1}{2*0,5088}= 0.9827
# \end{equation}
#
# \begin{equation}
# 2*γ-β^2= 1
# \end{equation}
#
# \begin{equation}
# β= \sqrt{2*γ-1}
# \end{equation}
#
# \begin{equation}
# γ^2= b
# \end{equation}
#
# \begin{equation}
# γ^2= \frac{1}{4} + a
# \end{equation}
#
# \begin{equation}
# γ= \sqrt{\frac{1}{4} + a}= \sqrt{\frac{1}{4} + α^2}= \sqrt{\frac{1}{4} + 0.9827^2}= 1,1026
# \end{equation}
#
# \begin{equation}
# β= \sqrt{2*γ-1}= \sqrt{2*1,1026-1}= 1,0978
# \end{equation}
#
# #####
# ##### Podemos expresar entonces la transferencia pasa bajos prototipo normalizada $T_{LP}(\$)$:
# #####
#
# \begin{equation}
# \boxed{T_{LP}($)=\frac{\frac{1}{2*ε}}{$^2 + \sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*$ + \frac{\sqrt{ε^2+1}}{2*ε}}= \frac{0.9827}{$^2 + 1,0978*$ + 1,1026}}
# \end{equation}
#
# #####
# ##### Aplicamos el núcleo de la transformación $K(s)= \$= \frac{1}{s}$ para obtener la transferencia pasa altos objetivo normalizada $T_{HP}(s)$:
# #####
#
# \begin{equation}
# T(s)= \frac {\frac{1}{2*ε}}{(\frac{1}{s})^2 + \sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*(\frac{1}{s}) + \frac{\sqrt{ε^2+1}}{2*ε}}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{\frac{1}{2*ε}}{\frac{1}{s^2} + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{s} + \frac{\sqrt{ε^2+1}}{2*ε}}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{\frac{1}{2*ε}}{\frac{1 +\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*s +\frac{\sqrt{ε^2+1}}{2*ε}*s^2}{s^2}}= \frac{\frac{1}{2*ε}*s^2}{1 +\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*s +\frac{\sqrt{ε^2+1}}{2*ε}*s^2}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{\frac{\frac{1}{2*ε}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s^2}{\frac{1 +\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*s +\frac{\sqrt{ε^2+1}}{2*ε}*s^2}{\frac{\sqrt{ε^2+1}}{2*ε}}}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac {\frac{\frac{1}{2*ε}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s^2} {\frac{1}{\frac{\sqrt{ε^2+1}}{2*ε}} +\frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s +\frac{\frac{\sqrt{ε^2+1}}{2*ε}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s^2}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac {\frac{1}{\sqrt{ε^2+1}}*s^2} {\frac{2*ε}{\sqrt{ε^2+1}} +\frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s +s^2}
# \end{equation}
#
# \begin{equation}
# T_{HP}(s)=\frac{\frac 1{\sqrt{ε^2+1}}*s^2}{s^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s + \frac{2*ε}{\sqrt{ε^2+1}}}
# \end{equation}
#
# \begin{equation}
# \boxed{T_{HP}(s)= \frac {0,8913*s^2} {s^2 +0,9957*s +0,9069}}
# \end{equation}
#
# #####
# ##### Considerando $T_{HP}(s)$ en términos de $\omega_0$ y $Q$, podemos expresarla de forma general de la siguiente manera:
# #####
#
# \begin{equation}
# T_{HP}(s)=\frac{k * s^2} {s^2 + \frac{ω_0}{Q}*s + ω_0^2}
# \end{equation}
#
#
# #####
# ##### Obtenemos los valores de $\omega_0$ y $Q$ para este caso particular:
# #####
#
# \begin{equation}
# ω_0^2= 0,9069
# \end{equation}
#
# \begin{equation}
# ω_0= 0,9523
# \end{equation}
#
# \begin{equation}
# \frac{ω_0}{Q}= 0,9957
# \end{equation}
#
# \begin{equation}
# Q= \frac{ω_0}{0,9957}= \frac{0,9523}{0,9957}= 0,9564
# \end{equation}
#
# #####
# ##### Obtenemos $T_{HP}(s)$ en términos de $\omega_0$ y $Q$, para este caso particular:
# #####
#
# \begin{equation}
# \boxed{T_{HP}(s)=\frac{0,8913*s^2} {s^2 + \frac{0,9523}{0,9564}*s + 0,9069}}
# \end{equation}
#
# #####
# ##### La $T_{HP}(s)$ anterior se trata de una transferencia normalizada y por lo general suele omitirse el correspondiente subíndice: lo correcto sería expresar dicha transferencia en términos de $s_N$.
# ##### Para desnormalizar la $T_{HP}(s)$ recordamos que $s_N= \frac{s}{\Omega_\omega}$ y siendo $\Omega_\omega= 2*\pi*4600 Hz$, obtenemos la transferencia del filtro pasa altos desnormalizada $T_{HP}(s)$:
# #####
#
# \begin{equation}
# T_{HP}(s)= \frac{ \frac{1}{\sqrt{ε^2+1}} * (\frac{s}{\Omega_\omega})^2 }{(\frac{s}{\Omega_\omega})^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*\frac{s}{\Omega_\omega} + \frac{2*ε}{\sqrt{ε^2+1}}}
# \end{equation}
#
# \begin{equation}
# T_{HP}(s)= \frac{ \frac{1}{\sqrt{ε^2+1}} * \frac{1}{\Omega_\omega^2} * s^2 } { \frac{1}{\Omega_\omega^2} * s^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}} * \frac{1}{\Omega_\omega} * s + \frac{2*ε}{\sqrt{ε^2+1}}}
# \end{equation}
#
# #####
# ##### Dejamos mónico el polinomio denominador:
# #####
#
# \begin{equation}
# T_{HP}(s)= \frac{ \frac{1}{\sqrt{ε^2+1}} * \frac{\Omega_\omega^2}{\Omega_\omega^2} * s^2} { \frac{\Omega_\omega^2}{\Omega_\omega^2}*s^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*\frac{\Omega_\omega^2}{\Omega_\omega}*s + \frac{2*ε}{\sqrt{ε^2+1}}*\Omega_\omega^2 }
# \end{equation}
#
# \begin{equation}
# T_{HP}(s)= \frac{ \frac{1}{\sqrt{ε^2+1}} * s^2} { s^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}} * \Omega_\omega * s + \frac{2*ε}{\sqrt{ε^2+1}}*\Omega_\omega^2 }
# \end{equation}
#
# \begin{equation}
# \boxed{T_{HP}(s)= \frac{0,8913*s^2} {s^2 +2,8777*10^4*s +7,5759*10^8}}
# \end{equation}
#
#
# #####
# #### <span style="text-decoration: underline;">Singularidades de $T_{HP}(s)$:</span>
# #####
#
# ##### La reciprocidad no tan es directa como, por caso, en un filtro Butterworth, cuyas las singularidades del denominador se encuentran en la circunsferencia de radio unitario y teniendo en cuenta que se dan de pares (complejas conjugadas) no alteran su posición dado que $\omega_0$ y $Q$ no cambian: los polos del filtro pasa bajos se convierten en los del filtro pasa altos. [$^{(6)}$](#6) [$^{(7)}$](#7)
#
# #####
#
# <img src="TPL1_PZ_LP2HP_Butterworth.png" style="margin-left:auto; margin-right:auto"/>
#
# #####
#
# ##### En el caso de un filtro pasa bajos Chevyshev, los polos se encuentran en una elipse, sin embargo, si bien es válida la reciprocidad, los polos de un filtro pasa altos Chevyshev no se encontrarán en la misma elipse.
#
# #####
#
# <img src="TPL1_PZ_LP2HP_Chevyshev.png" style="margin-left:auto; margin-right:auto"/>
#
# #####
#
# ##### Producto de la transformación, podemos observar que los ceros en el infinito se mapean al origen y los polos complejos conjugados se alternan sin modificar el sistema.[$^{(8)}$](#8) [$^{(9)}$](#9)
#
# #####
#
# <img src="TPL1_PZ_LP2HP_General.png" style="margin-left:auto; margin-right:auto"/>
#
# #####
#
# ##### Para $T_{HP}(s)=\frac{\frac 1{\sqrt{ε^2+1}}*s^2}{s^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s + \frac{2*ε}{\sqrt{ε^2+1}}}= \frac {0,8913*s^2} {s^2 +0,9957*s +0,9069}$, las singularidades son las siguientes:
#
# \begin{equation}
# z_{1,2}= 0
# \end{equation}
#
# \begin{equation}
# p_1= -0.4978 + j0.8118
# \end{equation}
#
# \begin{equation}
# p_2= -0.4978 - j0.8118
# \end{equation}
#
# #####
#
# ***
#
# #### <span style="text-decoration: underline;">Cálculo de los componentes externos del UAF42</span>
#
# #####
#
# ##### Utilizando las ecuaciones de diseño de la hoja de datos del UAF42:
#
# #####
#
# \begin{equation}
# ω_0^2= \frac{R_2}{R_1*R_{F1}*R_{F2}*C_1*C_2}
# \end{equation}
#
# #####
#
# \begin{equation}
# Q= \left( 1 + \frac{R_4}{R_Q} \right) * \frac{1}{\left(\frac{1}{R_1} + \frac{1}{R_2} + \frac{1}{R_G} \right)} * \sqrt{\frac{R_{F1}*C_1}{R_1*R_2*R_{F2}*C_2}}
# \end{equation}
#
# #####
#
# \begin{equation}
# A_{HP}= \frac{R_2}{R_G}
# \end{equation}
#
# #####
#
# ##### Tomando como norma de impedancia $Ω_z= R= 50KΩ$ y recordando que la norma de pulsación es $Ω_ω= ω_p= 2*\pi*4600 Hz$, obtenemos los componentes normalizados:
#
# #####
#
# \begin{equation}
# R_{1n}= \frac{R_1}{Ω_z}= \frac{R_1}{R}= 1
# \end{equation}
#
# \begin{equation}
# R_{2n}= \frac{R_2}{Ω_z}= \frac{R_2}{R}= 1
# \end{equation}
#
# \begin{equation}
# R_{4n}= \frac{R_4}{Ω_z}= \frac{R_4}{R}= 1
# \end{equation}
#
# \begin{equation}
# R_{F1n}= \frac{R_{F1}}{Ω_z}= \frac{R_{F1}}{R}= 2*10^{-5}\left[\frac{1}{Ω}\right]*R_{F1}
# \end{equation}
#
# \begin{equation}
# R_{F2n}= \frac{R_{F2}}{Ω_z}= \frac{R_{F2}}{R}= 2*10^{-5}\left[\frac{1}{Ω}\right]*R_{F2}
# \end{equation}
#
# \begin{equation}
# R_{Gn}= \frac{R_G}{Ω_z}= \frac{R_G}{R}= 2*10^{-5}\left[\frac{1}{Ω}\right]*R_G
# \end{equation}
#
# \begin{equation}
# R_{Qn}= \frac{R_Q}{Ω_z}= \frac{R_Q}{R}= 2*10^{-5}\left[\frac{1}{Ω}\right]*R_Q
# \end{equation}
#
# \begin{equation}
# C_{1n}= C_1*Ω_ω*Ω_z= C_1*ω_p*R= 1000pF * 2*π*4600\frac{rad}{s} * 50KΩ= 1,4451
# \end{equation}
#
# \begin{equation}
# C_{2n}= C_2*Ω_ω*Ω_z= C_2*ω_p*R= 1000pF * 2*π*4600\frac{rad}{s} * 50KΩ= 1,4451
# \end{equation}
#
# #####
#
# ##### Obtenemos los valores de $R_{F1n}$ y $R_{F2n}$ reemplazando los valores normalizados de los componentes en la ecuación de $ω_0^2$:
#
# #####
#
# \begin{equation}
# ω_0^2= \frac{R_{2n}}{R_{1n}*R_{F1n}*R_{F2n}*C_{1n}*C_{2n}} \frac{1}{4*10^{-5}*R_{F1}*R_{F2}*C_{1n}*C_{2n}}
# \end{equation}
#
# \begin{equation}
# R_{F1n}*R_{F2n}= \frac{R_{2n}}{R_{1n}*ω_0^2*C_{1n}*C_{2n}}
# \end{equation}
#
# \begin{equation}
# R_{F1n}*R_{F2n}= \frac{1}{1*0,9069*1,4451*1,4451}
# \end{equation}
#
# #####
#
# ##### Considerando $R_{F1n}= R_{F2n}$:
#
# #####
#
# \begin{equation}
# R_{F1n}= R_{F2n}= \sqrt{\frac{1}{0,9069*1,4451*1,4451}}= 0,7266
# \end{equation}
#
# #####
#
# ##### Obtenemos el valor de $R_{Gn}$, considerando que $A_{HP}= {T_{HP}(s)}\Bigr|_{s= j\omega} \rightarrow 0,8913$ para $\omega\rightarrow\infty$ y reemplazando su valor y el de los componentes normalizados en la ecuación correspondiente:
#
# #####
#
# \begin{equation}
# A_{HP}= \frac{R_{2n}}{R_{Gn}}
# \end{equation}
#
# \begin{equation}
# R_{Gn}= \frac{R_{2n}}{A_{HP}}
# \end{equation}
#
# \begin{equation}
# R_{Gn}= \frac{1}{0,8913}= 1,1219
# \end{equation}
#
# #####
#
# ##### Obtenemos el valor de $R_{Qn}$ reemplazando los valores normalizados de los componentes en la ecuación de $Q$:
#
# #####
#
# \begin{equation}
# Q= \left( 1 + \frac{R_{4n}}{R_{Qn}} \right) * \frac{1}{\left(\frac{1}{R_{1n}} + \frac{1}{R_{2n}} + \frac{1}{R_{Gn}} \right)} * \sqrt{\frac{R_{F1n}*C_{1n}}{R_{1n}*R_{2n}*R_{F2n}*C_{2n}}}
# \end{equation}
#
# \begin{equation}
# \frac{Q}{\frac{1}{\left(\frac{1}{R_{1n}} + \frac{1}{R_{2n}} + \frac{1}{R_{Gn}} \right)} * \sqrt{\frac{R_{F1n}*C_{1n}}{R_{1n}*R_{2n}*R_{F2n}*C_{2n}}}}= 1 + \frac{R_{4n}}{R_{Qn}}
# \end{equation}
#
# \begin{equation}
# \frac{Q}{\frac{1}{\left(\frac{1}{R_{1n}} + \frac{1}{R_{2n}} + \frac{1}{R_{Gn}} \right)} * \sqrt{\frac{R_{F1n}*C_{1n}}{R_{1n}*R_{2n}*R_{F2n}*C_{2n}}}}-1= \frac{R_{4n}}{R_{Qn}}
# \end{equation}
#
# \begin{equation}
# R_{Qn}= \frac{R_{4n}}{\frac{Q}{\frac{1}{\left(\frac{1}{R_{1n}} + \frac{1}{R_{2n}} + \frac{1}{R_{Gn}} \right)} * \sqrt{\frac{R_{F1n}*C_{1n}}{R_{1n}*R_{2n}*R_{F2n}*C_{2n}}}}-1}
# \end{equation}
#
# \begin{equation}
# R_{Qn}= \frac{1}{\frac{0,9564}{\frac{1}{\left(\frac{1}{1} + \frac{1}{1} + \frac{1}{1,1219} \right)} * \sqrt{\frac{0,7266*1,4451}{1*1*0,7266*1,4451}}}-1}= \frac{1} { 0,9564*\left(2 + \frac{1}{1,1219} \right)-1 }
# \end{equation}
#
# \begin{equation}
# R_{Qn}= 0,5665
# \end{equation}
#
# #####
#
# ##### <span style="text-decoration: underline;">Valores de componentes desnormalizados:</span>
#
# #####
#
# \begin{equation}
# R_1= 50KΩ
# \end{equation}
#
# \begin{equation}
# R_2= 50KΩ
# \end{equation}
#
# \begin{equation}
# R_4= 50KΩ
# \end{equation}
#
# \begin{equation}
# R_{F1}= R_{F1n}*Ω_z= 0,7266*50KΩ= 36,3300KΩ
# \end{equation}
#
# \begin{equation}
# R_{F2}= R_{F2n}*Ω_z= 0,7266*50KΩ= 36,3300KΩ
# \end{equation}
#
# \begin{equation}
# R_G= R_{Gn}*Ω_z= 1,1219*50KΩ= 56,0950KΩ
# \end{equation}
#
# \begin{equation}
# R_Q= R_{Qn}*Ω_z= 0,5665*50KΩ= 28,3250KΩ
# \end{equation}
#
# \begin{equation}
# C_1= 1000pF
# \end{equation}
#
# \begin{equation}
# C_2= 1000pF
# \end{equation}
#
# #####
#
# ##### <span style="text-decoration: underline;">Valores de componentes externos comerciales:</span>
#
# #####
# ##### Para llegar a los valores calculados, consideramos colocar una resistencia en serie con un preset de $5k\Omega$ para calibrar el valor deseado:
# #####
#
# \begin{equation}
# R_{F1}= R_{F11} + R_{F12}= 33k\Omega + 3,3k\Omega= 36,3k\Omega
# \end{equation}
#
# \begin{equation}
# R_{F2}= R_{F21} + R_{F22}= 33k\Omega + 3,3k\Omega= 36,3k\Omega
# \end{equation}
#
# \begin{equation}
# R_G= 56k\Omega + 950\Omega= 56,095k\Omega
# \end{equation}
#
# \begin{equation}
# R_Q= R_{Q1} + R_{Q2}= 27k\Omega + 1,325k\Omega= 28,325k\Omega
# \end{equation}
#
# #####
# ##### <span style="text-decoration: underline;">Nota:</span> Todos las resistencias serán al 5%:
# #####
# ##### Por ejemplo: $R_G= R_{G0} + \Delta R_{G}= 56k\Omega \pm 5\verb+%+$
# #####

# %% [markdown]
# #####
#
# ***
# ***
#
# #####
#
# ### <span style="text-decoration: underline;">Simulaciones</span>
#
# #####
# <a id="simulacion_numerica"></a>
# ### <span style="text-decoration: underline;">Simulación numérica</span>
# #####
#
# ##### Realice una simulación numérica/simbólica en Python de la función transferencia.
#
# #####

# %%
# ------------------------------------------------------------------------------------------------- #
# Librerias utilizadas
# ------------------------------------------------------------------------------------------------- #

import scipy.signal as sig
import sympy as sp
from sympy import N
import numpy as np
from numpy import pi

import matplotlib as mpl
from IPython.display import display, Markdown, Math

#from pytc2.sistemas_lineales import tf2sos_analog
from pytc2.sistemas_lineales import pretty_print_lti
from pytc2.sistemas_lineales import pretty_print_SOS
#from pytc2.sistemas_lineales import pretty_print_bicuad_omegayq
from pytc2.sistemas_lineales import analyze_sys
from pytc2.general import print_latex
#from pytc2.general import print_subtitle

# ------------------------------------------------------------------------------------------------- #

# %%
# ------------------------------------------------------------------------------------------------- #
# Ajustes de visualización
# ------------------------------------------------------------------------------------------------- #

fig_sz_x = 10
fig_sz_y = 9
fig_dpi = 150 # dpi

fig_font_size = 12

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
#plt.rcParams.update({'font.size':fig_font_size})

# ------------------------------------------------------------------------------------------------- #

# %%
# ------------------------------------------------------------------------------------------------- #
# Datos de plantilla
# ------------------------------------------------------------------------------------------------- #

alfa_max = 1                                    # dB
alfa_min = 20                                   # dB

f_s_plantilla = 1.2e3                           # Hz
f_p_plantilla = 4.6e3                           # Hz

omega_p_plantilla = 2*pi*f_p_plantilla
Omega_omega= omega_p_plantilla
omega_p_plantilla /= Omega_omega
omega_p_pb_prototipo = 1/omega_p_plantilla

omega_s_plantilla = 2*pi*f_s_plantilla
omega_s_plantilla /= Omega_omega
omega_s_pb_prototipo = 1/omega_s_plantilla

display(Markdown('***'))
display(Markdown('#####'))
display(Markdown('##### -- Datos de plantilla - Filtro pasa altos objetivo --'))
display(Markdown('#####'))

display(Math(r'\alpha_{min}= ' + sp.latex(alfa_min)))
display(Math(r'\alpha_{max}= ' + sp.latex(alfa_max)))
display(Math(r'fs= ' + sp.latex(f_s_plantilla)))
display(Math(r'fp= ' + sp.latex(f_p_plantilla)))

display(Markdown('#####'))
display(Markdown('##### -- Dominio transformado - Filtro pasa bajos prototipo --'))
display(Markdown('#####'))

display(Math(r'\omega_{p_{n}}= ' + sp.latex(N(omega_p_plantilla, 4))))
display(Math(r'\omega_{s_{n}}= ' + sp.latex(N(omega_s_plantilla, 4))))

display(Markdown('#####'))
display(Markdown('***'))

# ------------------------------------------------------------------------------------------------- #
# Out:
# ***
# #####
# ##### -- Datos de plantilla - Filtro pasa altos objetivo --
# #####
# $\displaystyle \alpha_{min}= 20$
# $\displaystyle \alpha_{max}= 1$
# $\displaystyle fs= 1200.0$
# $\displaystyle fp= 4600.0$
# #####
# ##### -- Dominio transformado - Filtro pasa bajos prototipo --
# #####
# $\displaystyle \omega_{p_{n}}= 1.0$
# $\displaystyle \omega_{s_{n}}= 0.2609$
# #####
# ***

# %%
# ------------------------------------------------------------------------------------------------- #
# Calculamos e^2
# ------------------------------------------------------------------------------------------------  #

display(Markdown('***'))
display(Markdown('#####'))
display(Markdown('##### -- $\epsilon$: Grado de libertad de la funcion --'))
display(Markdown('#####'))

display(Math(r'\epsilon = \sqrt{10^\frac{\alpha_{max}}{10}-1}'))
eps = np.sqrt(10**(alfa_max/10)-1)

display(Math(r'\epsilon= ' + sp.latex(N(eps, 4))))
display(Math(r'\epsilon^2= ' + sp.latex(N(eps**2, 4))))

display(Markdown('#####'))
display(Markdown('***'))

# ------------------------------------------------------------------------------------------------- #
# Out:
# ***
# #####
# ##### -- $\epsilon$: Grado de libertad de la funcion --
# #####
# $\displaystyle \epsilon = \sqrt{10^\frac{\alpha_{max}}{10}-1}$
# $\displaystyle \epsilon= 0.5089$
# $\displaystyle \epsilon^2= 0.2589$
# #####
# ***

# %%
# -------------------------------------------------------------------------------------------------- #
# Calculamos N iterando alfa_min
# -------------------------------------------------------------------------------------------------- #

display(Markdown('***'))
display(Markdown('#####'))
display(Markdown('-- $N$: Orden del filtro --'))
display(Markdown('#####'))
display(Math(r'\alpha_{min} = 10*log(1 + \epsilon^2*C_n^2) \quad ; \quad C_n^2= cosh^2\left[N*cosh^{-1}(\omega_s)\right]'))

for nn in range(1,10):
    C_nn = (np.cosh(nn*(np.arccosh(omega_s_pb_prototipo))))**2
    att = 10*np.log10(1+(eps**2)*C_nn)    
    display(Math(r'Para \quad N= ' + sp.latex(nn) + r': \quad ¿att= ' + sp.latex(N(att, 4)) + r'dB >= \alpha_{min}= ' + sp.latex(N(alfa_min, 4)) + r'?'))
    if att >= alfa_min:
        break
        
# Elegimos N de forma tal que α_min >= 20 dB:

display(Markdown('#####'))
display(Math('N= ' + sp.latex(nn)))
display(Markdown('#####'))
display(Markdown('***'))

# -------------------------------------------------------------------------------------------------- #
# Out:
# ***
# #####
# -- $N$: Orden del filtro --
# #####
# $\displaystyle \alpha_{min} = 10*log(1 + \epsilon^2*C_n^2) \quad ; \quad C_n^2= cosh^2\left[N*cosh^{-1}(\omega_s)\right]$
# $\displaystyle Para \quad N= 1: \quad ¿att= 6.817dB >= \alpha_{min}= 20.0?$
# $\displaystyle Para \quad N= 2: \quad ¿att= 23.22dB >= \alpha_{min}= 20.0?$
# #####
# $\displaystyle N= 2$
# #####
# ***

# %%
# ------------------------------------------------------------------------------------------------- #
# De la resolución analítica, obtenemos |T(jw)|^2 |w=s/j = 1 / (1 + ε^2*C_n^2) = T(s)*T(-s) 
# ------------------------------------------------------------------------------------------------- #

#Cn2 = 2w^2 - 1                 # Polinomio grado 2 de Chevyshev
Cn2 = [2, 0, -1]                # Coeficientes del polinomio grado 2 de Chevyshev
Cn4 = np.polymul(Cn2, Cn2)      # Elevamos al cuadrado el denominador
Cn4 = Cn4 * eps**2              # Multiplicamos por ε^2
Cn4[4]= Cn4[4] + 1              # Sumamos 1 al término independiente
Cn4[2]= -Cn4[2]                 # Cambiamos de signo al coeficiente del término cuadrático producto 
                                # del reeemplazo de w^2= s^2/j^2
Cn4 = Cn4 / (4*eps**2)          # Hacemos mónico el polinomio

# Obtenemos las raíces de Cn4 que se corresponden con los polos de |T(jw)|^2 |w=s/j = T(s)*T(-s):
p_T_lp= np.roots(Cn4)

# Seleccionamos aquellas raíces que se encuentren en el semiplano izquierdo correspondientes a T(s):
den_T_lp= np.poly([p_T_lp for p_T_lp in p_T_lp if p_T_lp.real < 0])

# Obtenemos el numerador de T(s):
num_T_lp= [np.sqrt(1/(4*eps**2))]

# Aplicamos el núcleo de la transformación pasa altos a través de la función lp2hp():
num_T_hp, den_T_hp= sig.lp2hp(num_T_lp, den_T_lp)

display(Markdown('#####'))
display(Markdown('-- z_i: Ceros obtenidos con roots(p) del polinomio numerador obtenido de forma analítica --'))
display(Markdown('#####'))

display(Math(r'z_{1,2}= ' + sp.latex(np.roots(num_T_hp))))

display(Markdown('#####'))
display(Markdown('-- p_i: Polos en el semiplano izquierdo obtenidos con roots(p) del polinomio denominador obtenido de forma analítica --'))
display(Markdown('#####'))

display(Math(r'p_{1,2}= ' + sp.latex(np.roots(den_T_hp))))

display(Markdown('#####'))
display(Markdown('***'))
# Out:
# #####
# -- z_i: Ceros obtenidos con roots(p) del polinomio numerador obtenido de forma analítica --
# #####
# $\displaystyle z_{1,2}= \mathtt{\text{[0. 0.]}}$
# #####
# -- p_i: Polos en el semiplano izquierdo obtenidos con roots(p) del polinomio denominador obtenido de forma analítica --
# #####
# $\displaystyle p_{1,2}= \mathtt{\text{[-0.49783403+0.8119004j -0.49783403-0.8119004j]}}$
# #####
# ***

# %%
#-------------------------------------------------------------------------------------------------------------------#

# Obtenemos singularidades con la función de aproximación de Chevyshev del 
# filtro pasa bajos prototipo: cheb1ap(N, rp)

z, p, k = sig.cheb1ap(nn, alfa_max)

#-------------------------------------------------------------------------------------------------------------------#

# Transformamos las singularidades que nos devuelve cheb1ap(N, rp) para obtener 
# el numerador y el denominador de la T_LP(s) del filtro pasa bajos prototipo 
# con zpk2tf(z,p,k):

num_lp, den_lp = sig.zpk2tf(z,p,k)

#-------------------------------------------------------------------------------------------------------------------#

# Transformamos la T_LP(s) del filtro pasa bajos prototipo para obtener 
# el numerador y el denominador de la T_HP(s) con lp2hp(num, den):

num_hp, den_hp = sig.lp2hp(num_lp, den_lp)

display(Markdown('#####'))
display(Markdown('-- $z_i$: Ceros obtenidos con cheb1ap(N, rp) coincidentes con los obtenidos con roots(p) de forma analítica --'))
display(Markdown('#####'))

display(Math(r'z_{1,2}= ' + sp.latex(np.roots(num_hp))))

display(Markdown('#####'))
display(Markdown('-- $p_i$: Polos en el semiplano izquierdo obtenidos con cheb1ap(N, rp) coincidentes con los obtenidos con roots(p) de forma analítica --'))
display(Markdown('#####'))

display(Math(r'p_{1,2}= ' + sp.latex(np.roots(den_hp))))

display(Markdown('#####'))
display(Markdown('***'))

#-------------------------------------------------------------------------------------------------------------------#

# Transformamos (factorizamos) la T(s) en secciones de segundo orden (SOS) con la función tf2sos_analog()
# this_sos = tf2sos_analog(num_hp, den_hp)

t_T_hp= sig.TransferFunction(num_T_hp, den_T_hp)             # numerador y denominador resolución analítica

t_hp= sig.TransferFunction(num_hp, den_hp)                   # numerador y denominador con cheb1ap()

#-------------------------------------------------------------------------------------------------------------------#

# Imprimimos la T_HP(s) en formato T_HP(s)= num/den con la funcion pretty_print_lti(num, den):

display(Markdown('#####'))
display(Markdown('-- Función transferencia $T_{HP}(s)$ analítica NORMALIZADA: --'))
display(Markdown('#####'))

pretty_print_lti(num_T_hp, den_T_hp)

display(Markdown('#####'))
display(Markdown('-- Función transferencia $T_{HP}(s)$ con $cheb1ap(N, rp)$ NORMALIZADA: --'))
display(Markdown('#####'))

pretty_print_lti(num_hp, den_hp)

display(Markdown('#####'))
display(Markdown('Función transferencia $T_{HP}(s)$ en términos de $k$, $\omega_0$ y $Q$ NORMALIZADA:'))
display(Markdown('#####'))

display(Math(r'$T_{HP}(s)= k \frac{ s^2 \frac{\omega_0}{Q} } { s^2 + s \frac{\omega_0}{Q} + \omega_0^2 } $'))
display(Markdown('#####'))

omega_0= np.sqrt(den_hp[2])
Q= omega_0/den_hp[1]
k= num_hp[0]/omega_0*Q

s = sp.symbols('s', complex=True)

print_latex('T_{HP}(s)= ' + sp.latex(N(k, 4)) + ' \\frac{ ' + sp.latex(s**2) + '\\frac{' + sp.latex(N(omega_0, 4)) + '}{' + sp.latex(N(Q, 4)) + '}' + '}{' + sp.latex(s**2) + ' + ' + sp.latex(s) + '\\frac{' + sp.latex(N(omega_0, 4)) + '}{' + sp.latex(N(Q, 4)) + '}' + ' + ' + sp.latex(N(omega_0**2, 4)) + '}')

display(Markdown('#####'))
display(Markdown('***'))

#-------------------------------------------------------------------------------------------------------------------#

# Representamos módulo, fase, diagrama de polos y ceros y retardo de fase con la función analyze_sys() que tiene, 
# entre otras cosas, indicadores (w0 y Q) de las singularidades en el diagrama de polos y ceros

display(Markdown('-- Módulo, fase, diagrama de polos y ceros y retardo de fase --'))
display(Markdown('#####'))

analyze_sys(t_hp, sys_name='High Pass Filter Chevyshev Order 2')

#-------------------------------------------------------------------------------------------------------------------#
# Out:
# #####
# -- $z_i$: Ceros obtenidos con cheb1ap(N, rp) coincidentes con los obtenidos con roots(p) de forma analítica --
# #####
# $\displaystyle z_{1,2}= \mathtt{\text{[0. 0.]}}$
# #####
# -- $p_i$: Polos en el semiplano izquierdo obtenidos con cheb1ap(N, rp) coincidentes con los obtenidos con roots(p) de forma analítica --
# #####
# $\displaystyle p_{1,2}= \mathtt{\text{[-0.49783403+0.8119004j -0.49783403-0.8119004j]}}$
# #####
# ***
# #####
# -- Función transferencia $T_{HP}(s)$ analítica NORMALIZADA: --
# #####
# $\displaystyle \frac{s^2 \,\, 0.8913 }{s^2 + s \,\, 0.9957 + 0.907 }$
# #####
# -- Función transferencia $T_{HP}(s)$ con $cheb1ap(N, rp)$ NORMALIZADA: --
# #####
# $\displaystyle \frac{s^2 \,\, 0.8913 }{s^2 + s \,\, 0.9957 + 0.907 }$
# #####
# Función transferencia $T_{HP}(s)$ en términos de $k$, $\omega_0$ y $Q$ NORMALIZADA:
# #####
# $\displaystyle T_{HP}(s)= k \frac{ s^2 \frac{\omega_0}{Q} } { s^2 + s \frac{\omega_0}{Q} + \omega_0^2 } $
# #####
# ...

# %% [markdown]
# #####
# ##### En la primera figura, se observa la respuesta de módulo de $T_{HP}(s)$.
# ##### Se observa que la pendiente de la banda de detención es $+40\frac{dB}{dec}$ debido al aporte de las singularidades del numerador mientras que en la banda de paso se ve compensada con el aporte de las singularidades del denominador debido a que el par de polos complejos conjugados aporta $−40\frac{dB}{dec}$.
# #####
# ##### En la segunda figura, se observa la respuesta de fase de $T_{HP}(s)$.
# ##### Se trata de una función sigmoidea monótonamente decreciente cuyo desarrollo de fase total es de $-\pi rad$ producto del aporte de fase del numerador y del denominador: $-\frac{\pi}{2}$ y $+\frac{\pi}{2}$ respectivamente, obteniendo el aporte total como la diferencia entre ellos.
# #####
# ##### En la tercera figura, se observa el diagrama de polos y ceros de $T_{HP}(s)$ que se corresponde con lo mencionado anteriormente en el análisis de singularidades.
# #####
# ##### En la cuarta figura, se observa la respuesta de retardo de grupo de $T_{HP}(s)$.
# ##### El retardo de grupo $\tau$ está dado por la variación de la respuesta de fase respecto a la frecuencia a través de su derivada de signo opuesto: $\tau=\frac{−\partial\Phi}{\partial\omega}$.
# ##### Observamos que en $\omega_0$, el retardo es máximo en concordancia con la pendiente de la recta tangente en ese punto.
# ##### A medida que nos desplazamos de dicha frecuencia, el retardo disminuye hasta anularse en los puntos en los que la pendiente de la recta tangente es mínima.
# #####

# %% [markdown]
# #####
#
# <img src="TPL1_Respuesta_modulo_HP_alpha_max.png" style="margin-left:auto; margin-right:auto"/>
#
# #####
# ##### En la figura se visualiza el máximo ripple en la banda de paso dado por $\alpha_{máx}= 1dB$ a la frecuencia $\omega_{p_{n}}= 1$.
# #####
#
# <img src="TPL1_Respuesta_modulo_HP_alpha_min.png" style="margin-left:auto; margin-right:auto"/>
#
# #####
# ##### En la figura se visualiza la atenuación mínima en la banda de detenida dado por $\alpha_{mín}$ a la frecuencia $\omega_{s_{n}}= 0,2609$.
# #####
# ##### Por lo tanto podemos afirmar que la simulación numérica se corresponde con la resolución analítica cumpliendo con los requerimientos de la plantilla objetivo pasa altos.
# #####

# %%
#-------------------------------------------------------------------------------------------------------------------#

# Calculamos transferencia desnormalizada: producto de la desnormalización y de dejar mónico el polinomio
# denominador, los términos quedan afectados por los siguientes factores (Ver resolución analítica T_HP(s)
# desnormalizada)

num_T_hp_ = num_T_hp
den_T_hp_ = den_T_hp * [1, Omega_omega, Omega_omega**2]

t_T_hp_= sig.TransferFunction(num_T_hp_, den_T_hp_)

#-------------------------------------------------------------------------------------------------------------------#

# Imprimimos la T(s) en formato T(s)= num/den con la funcion pretty_print_lti(num, den):

display(Markdown('#####'))
display(Markdown('-- Función transferencia T(s) analítica DESNORMALIZADA: --'))
display(Markdown('#####'))

pretty_print_lti(num_T_hp_, den_T_hp_)

display(Markdown('#####'))
display(Markdown('***'))
display(Markdown('#####'))

#-------------------------------------------------------------------------------------------------------------------#

display(Markdown('#####'))
display(Markdown('Función transferencia $T_{HP}(s)$ en términos de $k$, $\omega_0$ y $Q$ NORMALIZADA:'))
display(Markdown('#####'))

display(Math(r'$T_{HP}(s)= k \frac{ s^2 \frac{\omega_0}{Q} } { s^2 + s \frac{\omega_0}{Q} + \omega_0^2 } $'))
display(Markdown('#####'))

omega_0_d= np.sqrt(den_T_hp_[2])
Q_d= omega_0_d/den_T_hp_[1]
k_d= num_T_hp_[0]/omega_0_d*Q_d

s = sp.symbols('s', complex=True)

print_latex('T_{HP}(s)= ' + sp.latex(N(k, 4)) + ' \\frac{ ' + sp.latex(s**2) + '\\frac{' + sp.latex(N(omega_0_d, 4)) + '}{' + sp.latex(N(Q_d, 4)) + '}' + '}{' + sp.latex(s**2) + ' + ' + sp.latex(s) + '\\frac{' + sp.latex(N(omega_0_d, 4)) + '}{' + sp.latex(N(Q_d, 4)) + '}' + ' + ' + sp.latex(N(omega_0_d**2, 4)) + '}')

display(Markdown('#####'))
display(Markdown('***'))

#-------------------------------------------------------------------------------------------------------------------#

# Representamos módulo, fase, diagrama de polos y ceros y retardo de fase con la analyze_sys() que tiene, entre
# otras cosas, indicadores (w0 y Q) de las singularidades en el diagrama de polos y ceros

display(Markdown('-- Módulo, fase, diagrama de polos y ceros y retardo de fase --'))
display(Markdown('#####'))

analyze_sys(t_T_hp_, sys_name='High Pass Filter Chevyshev Order 2')

#-------------------------------------------------------------------------------------------------------------------#
# Out:
# #####
# -- Función transferencia T(s) analítica DESNORMALIZADA: --
# #####
# $\displaystyle \frac{s^2 \,\, 0.8913 }{s^2 + s \,\, 2.878e+04 + 7.577e+08 }$
# #####
# ***
# #####
# #####
# Función transferencia $T_{HP}(s)$ en términos de $k$, $\omega_0$ y $Q$ NORMALIZADA:
# #####
# $\displaystyle T_{HP}(s)= k \frac{ s^2 \frac{\omega_0}{Q} } { s^2 + s \frac{\omega_0}{Q} + \omega_0^2 } $
# #####
# $\displaystyle T_{HP}(s)= 0.8951 \frac{ s^{2}\frac{2.753 \cdot 10^{4}}{0.9565}}{s^{2} + s\frac{2.753 \cdot 10^{4}}{0.9565} + 7.577 \cdot 10^{8}}$
# #####
# ***
# -- Módulo, fase, diagrama de polos y ceros y retardo de fase --
# #####

# %% [markdown]
# #####
# ##### >>> ¡¡¡ VERIFICAR !!! <<<
# #####
# ##### Como se puede observar, desnormalizar $T_{HP}(s)$ únicamente afecta la escala y no la forma de las respectivas respuestas.
# ##### En el caso de la respuesta de módulo, fase y retardo de grupo, las gráficas se desplazan en el sentido positivo del eje $\omega$ mientras que en el diagrama de polos y ceros, los polos se desplazan a una elipse cuyos ejes son mayores productos de la desnormalización mientras que los ceros permanecen inmutables dado que se encuentran en el origen.
# #####

# %% [markdown]
# ***
#
# #####
# <a id="simulacion_circuital"></a>
# ### <span style="text-decoration: underline;">Simulación circuital</span>
# #####
#
# #### Realice la simulación circuital en Spice. Incluya un modelo discreto para simular el UAF42.
#
# #####

# %% [markdown]
# <img src="TPL1_Circuito_esquematico.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# #####
# ##### En la figura se observa el circuito propuesto por la hoja de datos del UAF42 cuyos componentes fueron calculados con anterioridad.
# #####
# ##### Cabe destacar además que se trata del filtro de variables de estado resuelto en la guía de OPAMP's y OTA's: >>> AGREGAR A RESOLUCIÓN EN DRIVE <<<
# #####
# ##### A continuación se mostrarán las respectivas respuestas de módulo, fase y retardo de grupo de la función transferencia de la salida del OPAMP $U_4$ respecto de la entrada que se corresponde con la $T_{HP}(s)$.
# #####
# ##### >>> QUIZÁS PUEDAN HACERSE COMENTARIOS RESPECTO DE LA TENSIÓN DE ALIMENTACIÓN ELEGIDA Y LOS PARÁMETROS DE LA SIMULACIÓN <<<
# #####
# ##### >>> Hacer algún comentario respecto a las diferencias en las respuestas de módulo, fase y retardo de grupo y a cómo responden los modelos de los componentes, sobre los OPAMPs, en alta frecuencia.
# #####
# ##### >>> VER DATO DE RESPUESTA EN FRECUENCIA EN LA HOJA DE DATOS DEL UAF42
# #####

# %% [markdown]
# #####
# #### En ambos casos obtener las gráficas de módulo, fase y retardo y compare los resultados.
# #####

# %% [markdown]
# #### <span style="text-decoration: underline;">Respuesta de módulo</span>
# #####
#
# <img src="TPL1_Respuesta_modulo_HP.png" style="margin-left:auto; margin-right:auto"/>
#
# #####
# #### <span style="text-decoration: underline;">Respuesta de fase</span>
# #####
#
# <img src="TPL1_Respuesta_fase_HP.png" style="margin-left:auto; margin-right:auto"/>
#
# #####
# #### <span style="text-decoration: underline;">Respuesta de retardo de grupo</span>
# #####
#
# <img src="TPL1_Respuesta_retardo_grupo_HP.png" style="margin-left:auto; margin-right:auto"/>
#
# #####

# %% [markdown]
# ***
# #####
# ### <span style="text-decoration: underline;">Armado del circuito:</span>
# #####
#
# ##### Armar el diseño en un circuito impreso o una placa experimental o bien en última instancia en una protoboard. Para el armado tenga en cuenta las siguientes recomendaciones:
# ##### Usar conectores, headers o borneras para poder alimentar el filtro, introducir la señal de entrada, medir la señal de entrada y medir la señal de salida ( test points ).
# ##### Un zócalo DIP14 (de 2x7 pines) para colocar el filtro UAF42 provisto por la Cátedra.
# ##### Incluir resistores variables para realizar el ajuste fino de algún parámetro del diseño.
# ##### En los puntos de alimentación del circuito integrado se recomienda agregar capacitores de bypass. Se sugiere agregar un capacitor electrolítico o de poliéster de 10µF a 68µF con otro cerámico de 100nF a 330nF en paralelo para reducir el ruido de la fuente.
#
# #####

# %% [markdown]
# ***
#
# #####
# <a id="referencias"></a>
# ### <span style="text-decoration: underline;">Referencias:</span>
# #####
#
# <a id="1"></a>
# ###### (1) Schaumann, Van Valkenburg, [*"Design of Analog Filters"*](https://drive.google.com/file/d/1Kmho8kfFZ_OevvB3TFCWTYMwIvEbg-hR/view?usp=sharing), Cáp.6.2: "Butterworth Response", Pág.254, Ec.6.6
#
# <a id="2"></a>
# ###### (2) Schaumann, Van Valkenburg, [*"Design of Analog Filters"*](https://drive.google.com/file/d/1Kmho8kfFZ_OevvB3TFCWTYMwIvEbg-hR/view?usp=sharing), Cáp.7.2: "The Chevyshev Magnitude Response", Pág.280, Ec.7.8
#
# <a id="3"></a>
# ###### (3) Schaumann, Van Valkenburg, [*"Design of Analog Filters"*](https://drive.google.com/file/d/1Kmho8kfFZ_OevvB3TFCWTYMwIvEbg-hR/view?usp=sharing), Cáp.7.2: "The Chevyshev Magnitude Response", Pág.281, Ec.7.14
#
# <a id="4"></a>
# ###### (4) Schaumann, Van Valkenburg, [*"Design of Analog Filters"*](https://drive.google.com/file/d/1Kmho8kfFZ_OevvB3TFCWTYMwIvEbg-hR/view?usp=sharing), Cáp.7.2: "The Chevyshev Magnitude Response", Pág.282, Ec.7.17
#
# <a id="5"></a>
# ###### (5) Schaumann, Van Valkenburg, [*"Design of Analog Filters"*](https://drive.google.com/file/d/1Kmho8kfFZ_OevvB3TFCWTYMwIvEbg-hR/view?usp=sharing), Cáp.7.1: "The Chevyshev Polinomial", Pág.279, Ec.7.7
#
# <a id="6"></a>
# ###### (6) Schaumann, Van Valkenburg, [*"Design of Analog Filters"*](https://drive.google.com/file/d/1Kmho8kfFZ_OevvB3TFCWTYMwIvEbg-hR/view?usp=sharing), Cáp.9.1: "Lowpass-To-Highpass Transformation", Pág.348-350
#
# <a id="7"></a>
# ###### (7) Llamedo Soria, [*"Teoría de Filtrado Moderna: Funciones de aproximación"*](https://pytc2.readthedocs.io/en/latest/ComparativaOrdenes.html), Aproximaciones de Butterworth.
#
# <a id="8"></a>
# ###### (8) Schaumann, Van Valkenburg, [*"Design of Analog Filters"*](https://drive.google.com/file/d/1Kmho8kfFZ_OevvB3TFCWTYMwIvEbg-hR/view?usp=sharing), Cáp.9.1: "Lowpass-To-Highpass Transformation", Pág.348-349
#
# <a id="9"></a>
# ###### (9) Llamedo Soria, [*"Teoría de Filtrado Moderna: Funciones de aproximación"*](https://pytc2.readthedocs.io/en/latest/ComparativaOrdenes.html), Aproximaciones de Chevyshev.
#
# #####
#
# ***
# ***
#
# #####

# %% [markdown]
# ##### © Copyright 2023, Moharos, David Santiago. Revision 1.0.0.
# ***

# %% [markdown]
# <img src="TS11_Logo_UTN.svg" align="right" width="150" />
#
# ##
#
# ***
#
# ## (950431) Teoría de Circuitos II
#
# ***
#
# ##
# #### Profesor: Mariano Llamedo Soria  <llamedom@frba.utn.edu.ar>
# #### Jefe de TPs: César Fuoco  <cfuoco@frba.utn.edu.ar>
# #### Ayudante de TPs: Israel Pavelek <pavel@frba.utn.edu.ar>
# ##

# %% [markdown]
# ***
# ***
#
# ##
# ## Trabajo Semanal # 11 - Funciones de excitación disipativas
# ##
#
# ***
# ***
#
# ##
# ### <span style="text-decoration: underline;">Autor</span>
# #### *Moharos, David Santiago* <dmoharos@frba.utn.edu.ar>
# ##
#
# ***

# %% [markdown]
# ##
# <a id="indice"></a>
# ### <span style="text-decoration: underline;">Indice</span>
# ##
# ##### [Ejercicio # 1](#ejercicio_1)
# ###
# ##### [Ejercicio # 2](#ejercicio_2)
# ###
# ##### [Bibliografía sugerida](#bibliografia)
# ##
#
# ***

# %% [markdown]
# ***
# ##
#
# <a id="ejercicio_1"></a>
# <img src="TS11_Ejercicio_1.png" style="margin-left:auto; margin-right:auto"/>
#
# ###### [Volver al índice](#indice)

# %% [markdown]
# ***
# ###
# #### <u>Resolución analítica</u>
# ###
#
# ###
# ##### Factorizamos y reescribimos la función excitación $Z(s)$ para expresarla estrictamente en función de sus singularidades:
# ###
#
# \begin{equation*}
# Z(s) = \frac{ s^2 +6s +8 }{ s^2 +4s +3 } = \frac{ ( s + 2 )( s + 4 ) }{ ( s + 1 )( s + 3 ) }
# \end{equation*}
#
# ###
# ##### Como se puede observar, la función $Z(s)$ presenta:
# ###### -Un cero simple en $\omega = 2$,
# ###### -Un cero simple en $\omega = 4$,
# ###### -Un polo simple en $\omega = 1$,
# ###### -Un polo simple en $\omega = 3$,
# ###
# ##### Realizamos un estudio de la función en los extremos para ver su comportamiento:
# ###
#
# \begin{equation*}
# \lim_{s -> 0} Z(s) = \lim_{s -> 0} \frac{ s^2 +6s +8 }{ s^2 +4s +3 } = \frac{8}{3}
# \end{equation*}
#
# ###
#
# \begin{equation*}
# \lim_{ s -> \infty } Z(s) = \lim_{ s -> \infty } \frac{ s^2 + 6s + 8 }{ s^2 + 4 s + 3 } = 1
# \end{equation*}
#
# ###
# ##### Obtenemos valores finitos en ambos extremos que serán asociados, como no puede ser de otra manera, a algún arreglo de resistencias y que nos permite determinar la naturaleza RC del circuito.
# ###
#
# <img src="TS11_Ejercicio_1_Circuito_Naturaleza_RC.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
# ##### <u>Diagrama de singularidades de $Z(s)$</u>
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_0.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
# ##### <u>Paso 1:</u> Remoción parcial en infinito para sintonizar el tanque en derivación compuesto por $R_1C_1$ a $\omega= 6$ producto de lo solicitado por el enunciado mediante la constante de tiempo $R_1C_1 = \frac{1}{6}$:
# ###
# ##### Obtenemos el residuo de forma analítica:
# ###
#
# \begin{equation*}
# Z(s) = Z_1(s) + Z_2(s) = k_\infty' + Z_2(s)
# \end{equation*}
#
# ###
# ##### En la frecuencia de interés, sucede que:
# ###
#
# \begin{equation*}
# \lim_{s -> (-6)} Z_2(s) = 0
# \end{equation*}
#
# ###
# ##### Operamos algebraicamente y obtenemos $k_\infty'$ como:
# ###
#
# \begin{equation*}
# k_\infty' = \lim_{s -> (-6)} Z(s)
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_\infty' = \lim_{{s -> (-6)}} \frac { s^2 + 6s +8 }{ s^2 + 4s +3 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_\infty' = \frac{ (-6)^2 + 6(-6) + 8 }{ (-6)^2 + 4(-6) + 3 } = \frac{ 8 }{ 15 }
# \end{equation*}
#
# ###
# ##### Respetando la nomenclatura del circuito, expresamos:
# ###
#
# \begin{equation*}
# Ra = k_\infty' = \frac{ 8 }{ 15 }
# \end{equation*}
#
# ###
# ##### Finalmente obtenemos $Z_2(s)$ como:
# ###
#
# \begin{equation*}
# Z_2(s) = Z(s) - Z_1(s) = Z(s) - k_\infty'
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_2(s) = \frac{ s^2 +6s +8 }{ s^2 +4s +3 } - \frac{8}{15}
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_2(s) = \frac{ 15(s^2 +6s +8) - 8(s^2 +4s +3) }{ 15(s^2 +4s +3) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_2(s) = \frac{ 15s^2 +90s +120 - 8s^2 -32s -24 }{ 15(s^2 +4s +3) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_2(s) = \frac{ 7s^2 +58s +96 }{ 15(s^2 +4s +3) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_2(s) = \frac{7}{15} \frac{ s^2 +\frac{58}{7}s +\frac{96}{7} }{ s^2 +4s +3 }
# \end{equation*}
#
# ###
# ##### Factorizamos para poner de manifesto las singularidades:
# ###
#
# \begin{equation*}
# Z_2(s) = \frac{ 7 }{ 15 } \frac{ ( s + \frac{ 16 }{ 7 } )( s + 6 ) }{ ( s + 1 )( s + 3 ) }
# \end{equation*}
#
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_1.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
# ##### Como se observa, producto de la remoción parcial, los valores finitos en los extremos disminuyen en la misma proporción, el cero que se situaba en $\sigma = -4$ se desplaza hacia $\sigma = -6$, el cero en $\sigma = -2$ se desplaza hacia la zona de remoción, mientras que los polos permanecen en su lugar.
# ###
#
# ###
# ##### <u>Paso 2:</u> Inversión de la función $Z_2(s)$: se invierten los valores finitos y los ceros se reemplazan por polos y viceversa.
# ###
#
# \begin{equation*}
# Y_2(s) = \frac{ 1 }{ Z_2(s) } = \frac{ 15 }{ 7 } \frac{ ( s + 1 )( s + 3 ) }{ ( s + \frac{ 16 }{ 7 } )( s + 6 ) }
# \end{equation*}
#
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_2.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
# ##### <u>Paso 3:</u> Remoción total del tanque en derivación compuesto por $R_1C_1$ sintonizado a $\omega= 6$.
# ###
# ###
# ##### Obtenemos el residuo de forma analítica:
# ###
#
# \begin{equation*}
# Y_j(s) = lim_{s -> (-\sigma_i)} \left[ Y_i(s) \right] = \frac{ sk_i }{ s + \sigma_i } = \frac{ 1 }{ \frac{ s }{ sk_i } + \frac{ \sigma_i }{ sk_i } } = \frac{ 1 }{ \frac{ 1 }{ k_i } + \frac{ 1 }{ s \frac{ k_i }{ \sigma_i } } } = \frac{ 1 }{ R_i + \frac{ 1 }{ sC_i } }
# \end{equation*}
#
# ###
# ##### En este caso:
# ###
#
# \begin{equation*}
# Y_3(s) = lim_{s -> (-6)} \left[ Y_2(s) \right] = \frac{ sk_3 }{ s + 6 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_3 = lim_{s -> (-6)} \left[ Y_2(s) \cdot \frac{ s + 6 }{ s } \right]
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_3 = lim_{s -> (-6)} \left[  \frac{ 15 }{ 7 } \frac{ ( s + 1 )( s + 3 ) }{ ( s + \frac{ 16 }{ 7 } )( s + 6 ) } \frac{ ( s + 6 ) }{ s } \right]
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_3 = lim_{s -> (-6)} \left[ \frac{ 15 }{ 7 } \frac{ ( s + 1 )( s + 3 ) }{ ( s + \frac{ 16 }{ 7 } )s } \right]
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_3 = lim_{s -> (-6)} \left[ \frac{ 15 }{ 7 } \frac{ ( -6 + 1 )( -6 + 3 ) } { (-6 + \frac{ 16 }{ 7 } )(-6) } \right] = \frac{ 75 }{ 52 }
# \end{equation*}
#
# ###
# ##### Habiendo calculado el residuo $k_3$, obtenemos los valores de los componentes que constituyen el tanque en derivación, $R_1$ y $C_1$, y por supuesto $Y_3(s)$:
# ###
#
# \begin{equation*}
# R_1 = \frac{ 1 }{ k_3 } = \frac{ 1 }{ \frac{ 75 }{ 52 } } = \frac{ 52 }{ 75 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# C_1 = \frac{ k_3 }{ \sigma_3 } = \frac{ \frac{ 75 }{ 52 } }{ 6 } = \frac{ 25 }{ 104 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_3(s) = \frac{ sk_3 }{ s + 6 } = \frac{ s \frac{ 75 }{ 52 } }{ s + 6 }
# \end{equation*}
#
# ###
# ##### Finalmente obtenemos $Y_4(s)$ como:
# ###
#
# \begin{equation*}
# Y_4(s) = Y_2(s) - Y_3(s)
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ 15 }{ 7 } \frac{ ( s + 1 )( s + 3 ) } { ( s + \frac{ 16 }{ 7 } )( s + 6 ) } -  \frac{ s \frac{ 75 }{ 52 } }{ s + 6 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ \frac{ 15 }{ 7 } ( s + 1 )( s + 3 ) -  s \frac{ 75 }{ 52 }( s + \frac{ 16 }{ 7 } ) } { ( s + \frac{ 16 }{ 7 } )( s + 6 ) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ \frac{ 15 }{ 7 } s^2 + \frac{ 60 }{ 7 } s + \frac{ 45 }{ 7 }  - \frac{ 75 }{ 52 }s^2 - \frac{ 300 }{ 91 }s } { ( s + \frac{ 16 }{ 7 } )( s + 6 ) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ \frac{ 255 }{ 364 }s^2 + \frac{ 480 }{ 91 }s + \frac{ 45 }{ 7 } } { ( s + \frac{ 16 }{ 7 } )( s + 6 ) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ 255 }{ 364 } \frac{ \left( s^2 + \frac{ 128 }{ 17 }s + \frac{ 156 }{ 17 } \right) } { ( s + \frac{ 16 }{ 7 } )( s + 6 ) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ 255 }{ 364 } \frac{ \left( s + \frac{ 26 }{ 17 } \right)( s + 6 ) } { ( s + \frac{ 16 }{ 7 } )( s + 6 ) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ 255 }{ 364 } \frac{ \left( s + \frac{ 26 }{ 17 } \right) } { \left( s + \frac{ 16 }{ 7 } \right) }
# \end{equation*}
#
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_3.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
# ##### Como se observa, producto de la remoción total del tanque en derivación:
# ###### - El valor finito en continua permanece constante, no así en infinito que disminuye,
# ###### - El cero que se situaba en $\sigma = -3$ se cancela con el polo ubicado en $\sigma = -6$,
# ###### - El cero en $\sigma = -1$ se desplaza hacia la zona de remoción,
# ###### - Los polos permanecen en su lugar.
# ###
#
# ###
# ##### <u>Paso 4:</u> Inversión de la función $Y_4(s)$: se invierten los valores finitos y los ceros se reemplazan por polos y viceversa.
# ###
#
# ###
#
# \begin{equation*}
# Z_4(s) = \frac{ 1 }{ Y_4(s) } = \frac{ 364 }{ 255 } \frac{ \left( s + \frac{ 16 }{ 7 } \right) } { \left( s + \frac{ 26 }{ 17 } \right) }
# \end{equation*}
#
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_4.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
#
# ###
# ##### <u>Paso 5:</u> Remoción parcial en infinito para sintonizar el tanque en derivación compuesto por $R_2C_2$ a $\omega= \frac{7}{2}$ producto de lo solicitado por el enunciado mediante la constante de tiempo $R_2C_2 = \frac{2}{7}$:
# ###
# ##### Obtenemos el residuo de forma analítica:
# ###
#
# \begin{equation*}
# Z_4(s) = Z_5(s) + Z_6(s) = k'_{{\infty}_2} + Z_6(s)
# \end{equation*}
#
# ###
# ##### En la frecuencia de interés, sucede que:
# ###
#
# \begin{equation*}
# \lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } Z_6(s) = 0
# \end{equation*}
#
# ###
# ##### Operamos algebraicamente y obtenemos $k_\infty'$ como:
# ###
#
# \begin{equation*}
# k'_{{\infty}_2} = \lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } Z_4(s)
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k'_{{\infty}_2} = \lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } \frac{ 364 }{ 255 } \frac{ \left( s + \frac{ 16 }{ 7 } \right) } { \left( s + \frac{ 26 }{ 17 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k'_{{\infty}_2} = \lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } \frac{ 364 }{ 255 } \frac{ \left( -\frac{ 7 }{ 2 } + \frac{ 16 }{ 7 } \right) } { \left( -\frac{ 7 }{ 2 } + \frac{ 26 }{ 17 } \right) } = \frac{ 884 }{ 1005 }
# \end{equation*}
#
# ###
# ##### Respetando la nomenclatura del circuito, expresamos:
# ###
#
# \begin{equation*}
# Rb = k'_{{\infty}_2} = \frac{ 884 }{ 1005 }
# \end{equation*}
#
# ###
# ##### Finalmente obtenemos $Z_6(s)$ como:
# ###
#
# \begin{equation*}
# Z_6(s) = Z_4(s) - Z_5(s) = Z_4(s) - k'_{{\infty}_2}
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ 364 }{ 255 } \frac{ \left( s + \frac{ 16 }{ 7 } \right) } { \left( s + \frac{ 26 }{ 17 } \right) } - \frac{ 884 }{ 1005 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ \frac{ 364 }{ 255 } 1005 \left( s + \frac{ 16 }{ 7 } \right) - 884 \left( s + \frac{ 26 }{ 17 } \right)} { 1005 \left( s + \frac{ 26 }{ 17 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ \frac{ 364 }{ 255 } 1005 s + \frac{ 364 }{ 255 } 1005 \frac{ 16 }{ 7 }  - 884 s - 884 \frac{ 26 }{ 17 } }{ 1005 \left( s + \frac{ 26 }{ 17 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ \left( \frac{ 364 }{ 255 } 1005 - 884 \right) s + \frac{ 364 }{ 255 } 1005 \frac{ 16 }{ 7 } - 884 \frac{ 26 }{ 17 } }{ 1005 \left( s + \frac{ 26 }{ 17 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ \frac{ 9360 }{ 17 } s + \frac{ 32760 }{ 17 } }{ 1005 \left( s + \frac{ 26 }{ 17 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ 624 }{ 1139 } \frac{ \left( s + \frac{ 7 }{ 2 } \right) }{ \left( s + \frac{ 26 }{ 17 } \right) }
# \end{equation*}
#
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_5.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
#
# ###
# ##### <u>Paso 6:</u> Inversión de la función $Z_6(s)$: se invierten los valores finitos y los ceros se reemplazan por polos y viceversa.
# ###
#
# ###
#
# \begin{equation*}
# Y_6(s) = \frac{ 1 }{ Z_6(s) } = \frac{ 1139 }{ 624 } \frac{ \left( s + \frac{ 26 }{ 17 } \right) }{ \left( s + \frac{ 7 }{ 2 } \right) }
# \end{equation*}
#
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_6.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
# ###
# ##### <u>Paso 7:</u> Remoción total del tanque en derivación compuesto por $R_2C_2$ sintonizado a $\omega= \frac{ 7 }{ 2 }$.
# ###
# ###
# ##### Obtenemos el residuo de forma analítica:
# ###
#
# \begin{equation*}
# Y_j(s) = lim_{s -> (-\sigma_i)} \left[ Y_i(s) \right] = \frac{ sk_i }{ s + \sigma_i } = \frac{ 1 }{ \frac{ s }{ sk_i } + \frac{ \sigma_i }{ sk_i } } = \frac{ 1 }{ \frac{ 1 }{ k_i } + \frac{ 1 }{ s \frac{ k_i }{ \sigma_i } } } = \frac{ 1 }{ R_i + \frac{ 1 }{ sC_i } }
# \end{equation*}
#
# ###
# ##### En este caso:
# ###
#
# \begin{equation*}
# Y_7(s) = lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } \left[ Y_6(s) \right] = \frac{ sk_7 }{ s + \frac{ 7 }{ 2 } }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_7 = lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } \left[ Y_6(s) \cdot \frac{ s + \frac{ 7 }{ 2 } }{ s } \right]
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_7 = lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } \left[ \frac{ 1139 }{ 624 } \frac{ \left( s + \frac{ 26 }{ 17 } \right) }{ \left( s + \frac{ 7 }{ 2 } \right) } \frac{ ( s + \frac{ 7 }{ 2 } ) }{ s } \right]
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_7 = lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } \left[ \frac{ 1139 }{ 624 } \frac{ \left( s + \frac{ 26 }{ 17 } \right) }{ s } \right]
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_7 = lim_{ s -> \left( -\frac{ 7 }{ 2 } \right) } \left[ \frac{ 1139 }{ 624 } \frac{ \left( -\frac{ 7 }{ 2 } + \frac{ 26 }{ 17 } \right) }{ \left( -\frac{ 7 }{ 2 } \right) } \right] = \frac{ 4489 }{ 4368 }
# \end{equation*}
#
# ###
# ##### Habiendo calculado el residuo $k_7$, obtenemos los valores de los componentes que constituyen el tanque en derivación, $R_2$ y $C_2$, y por supuesto $Y_7(s)$:
# ###
#
# \begin{equation*}
# R_2 = \frac{ 1 }{ k_7 } = \frac{ 1 }{ \frac{ 4489 }{ 4368 } } = \frac{ 4368 }{ 4489 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# C_2 = \frac{ k_7 }{ \sigma_7 } = \frac{ \frac{ 4489 }{ 4368 } }{ \frac{ 7 }{ 2 } } = \frac{ 4489 }{ 15288 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_7(s) = \frac{ sk_7 }{ s + \frac{ 7 }{ 2 } } = \frac{ s \frac{ 4489 }{ 4368 } }{ s + \frac{ 7 }{ 2 } }
# \end{equation*}
#
# ###
# ##### Finalmente obtenemos $Y_8(s)$ como:
# ###
#
# \begin{equation*}
# Y_8(s) = Y_6(s) - Y_7(s)
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_8(s) =
# \frac{ 1139 }{ 624 } \frac{ \left( s + \frac{ 26 }{ 17 } \right) }{ \left( s + \frac{ 7 }{ 2 } \right) } -
# \frac{ s \frac{ 4489 }{ 4368 } }{ s + \frac{ 7 }{ 2 } }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_8(s) = \frac{ \frac{ 1139 }{ 624 } \left( s + \frac{ 26 }{ 17 } \right) - s \frac{ 4489 }{ 4368 } }{ \left( s + \frac{ 7 }{ 2 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_8(s) = \frac{ \frac{ 1139 }{ 624 }s + \frac{ 1139 }{ 624 }\frac{ 26 }{ 17 } - s \frac{ 4489 }{ 4368 } }{ \left( s + \frac{ 7 }{ 2 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_8(s) = \frac{ \left( \frac{ 1139 }{ 624 } - \frac{ 4489 }{ 4368 } \right)s + \frac{ 1139 }{ 624 }\frac{ 26 }{ 17 } }{ \left( s + \frac{ 7 }{ 2 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_8(s) = \frac{ \left( \frac{ 67 }{ 84 }s + \frac{ 67 }{ 24 } \right) }{ \left( s + \frac{ 7 }{ 2 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_8(s) = \frac{ 67 }{ 84 } \frac{ \left( s + \frac{ 7 }{ 2 } \right) }{ \left( s + \frac{ 7 }{ 2 } \right) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_8(s) = \frac{ 67 }{ 84 }
# \end{equation*}
#
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_7.png" style="margin-left:auto; margin-right:auto"/>
#
# ###
# ##### Como se observa, producto de la remoción total del tanque en derivación:
# ###### -El valor finito en continua permanece constante, no así en infinito que disminuye,
# ###### -El cero que se situaba en $\sigma = -\frac{ 26 }{ 17 }$ se cancela con el polo ubicado en $\sigma = -\frac{ 7 }{ 2 }$.
# ###
#
# ###
# ##### <u>Paso 8:</u> Remoción total de la resistencia $Rc$ en serie para finalizar la síntesis.
# ###
#
# \begin{equation*}
# R_c = \frac{ 1 }{ Y_9(s) } = \frac{ 1 }{ \frac{ 67 }{ 84 } } =  \frac{ 84 }{ 67 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_{10}(s) = Y_8(s) - Y_9(s) = \frac{ 67 }{ 84 } - \frac{ 67 }{ 84 } = 0
# \end{equation*}
#
# ###
#
# <img src="TS11_Ejercicio_1_PZmap_Paso_8.png" style="margin-left:auto; margin-right:auto"/>
#
# ###

# %%
#---------------------------------------------------------------------------------------------------------------------#
#-- Resolución simbólica --
#---------------------------------------------------------------------------------------------------------------------#

import sympy            as     sp
from   pytc2.remociones import remover_valor, remover_polo_sigma
from   pytc2.dibujar    import dibujar_puerto_entrada, dibujar_funcion_exc_abajo, dibujar_elemento_serie 
from   pytc2.dibujar    import dibujar_elemento_derivacion, dibujar_espacio_derivacion, dibujar_tanque_RC_derivacion
from   pytc2.dibujar    import display, Resistor, Capacitor
from   pytc2.general    import print_latex, print_subtitle, a_equal_b_latex_s
from   IPython.display  import display, Markdown, Math

#---------------------------------------------------------------------------------------------------------------------#
#-- Función de excitación Y(s)
#---------------------------------------------------------------------------------------------------------------------#

s = sp.symbols( 's', complex = True )

# Sea la siguiente función de excitación
Z = ( s**2 + 6*s + 8 ) / ( s**2 + 4*s + 3 )

display( Markdown( '###' ) )
print_subtitle( '<u>Impedancia de entrada a la red</u>' )
display( Markdown( '###' ) )
print_latex( a_equal_b_latex_s( 'Z(s)', Z ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Circuito propuesto con referencias
#---------------------------------------------------------------------------------------------------------------------#

display( Markdown( '###' ) )
print_subtitle( '<u>Circuito propuesto con referencias</u>' )
display( Markdown( '###' ) )

d = dibujar_puerto_entrada( '', voltage_lbl = ('+', '$V$', '-'), current_lbl = '$I$' )
d, zz_lbl = dibujar_funcion_exc_abajo( d, 'Z', Z, hacia_salida = True, k_gap_width = 0.5 )
d = dibujar_elemento_serie( d, Resistor, 'Ra' )
d = dibujar_tanque_RC_derivacion( d, 'R1', 'C1' )
d = dibujar_elemento_serie( d, Resistor, 'Rb' )
d = dibujar_tanque_RC_derivacion( d, 'R2', 'C2' )
d = dibujar_espacio_derivacion( d )
d = dibujar_elemento_derivacion( d, Resistor, 'Rc' )
display( d )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 1: Remoción parcial en infinito para sintonizar el tanque en derivación compuesto por $R_1C_1$ a $\omega= 6$
#-- producto de lo solicitado por el enunciado mediante la constante de tiempo $R_1C_1 = \frac{1}{6}$:
#---------------------------------------------------------------------------------------------------------------------#

sigma3 = 6
Z2, Ra = remover_valor( Z, sigma_zero = sigma3 )

display( Markdown( '###' ) )
print_latex( a_equal_b_latex_s( 'Z_1(s) = Ra', Ra ) )
display( Markdown( '###' ) )
print_latex( a_equal_b_latex_s( 'Z_2(s)', Z2 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 2: Inversión de la función $Z_2(s)$: se invierten los valores finitos y los ceros se reemplazan por 
#-- polos y viceversa.
#---------------------------------------------------------------------------------------------------------------------# 

Y2 = 1/Z2

print_latex( a_equal_b_latex_s( 'Y_2(s)', Y2 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------# 
#-- Paso 3: Remoción total del tanque en derivación compuesto por $R_1C_1$ sintonizado a $\omega= 6$.
#---------------------------------------------------------------------------------------------------------------------# 

Y4, Y3, R1, C1 = remover_polo_sigma( Y2, sigma3, isImpedance = False )

print_latex( a_equal_b_latex_s( 'Y_3(s)', Y3 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'R_1', R1 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'C_1', C1 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Y_4(s)', Y4 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 4: Inversión de la función $Y_4(s)$: se invierten los valores finitos y los ceros se reemplazan por 
#-- polos y viceversa.
#---------------------------------------------------------------------------------------------------------------------#

Z4 = 1/Y4

print_latex( a_equal_b_latex_s( 'Z_4(s)', Z4 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 5: Remoción parcial en infinito para sintonizar el tanque en derivación compuesto por $R_2C_2$ a 
#-- $\omega= \frac{7}{2}$ producto de lo solicitado por el enunciado mediante la constante de tiempo 
#-- $R_2C_2 = \frac{2}{7}$:
#---------------------------------------------------------------------------------------------------------------------#

sigma7 = sp.Rational('7/2')
Z6, Rb = remover_valor( Z4, sigma_zero = sigma7 )

print_latex( a_equal_b_latex_s( 'Z_5(s) = Rb', Rb ) )
display( Markdown( '###' ) )
print_latex( a_equal_b_latex_s( 'Z_6(s)', Z6 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------# 
#-- Paso 6:</u> Inversión de la función $Z_6(s)$: se invierten los valores finitos y los ceros se reemplazan por 
#-- polos y viceversa.
#---------------------------------------------------------------------------------------------------------------------# 

Y6 = 1/Z6

print_latex( a_equal_b_latex_s( 'Y_6(s)', Y6 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------# 
#-- Paso 7: Remoción total del tanque en derivación compuesto por $R_2C_2$ sintonizado a $\omega= \frac{ 7 }{ 2 }$.
#---------------------------------------------------------------------------------------------------------------------# 

Y8, Y7, R2, C2 = remover_polo_sigma( Y6, sigma7, isImpedance = False )

print_latex( a_equal_b_latex_s( 'Y_7(s)', Y7 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'R_2', R2 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'C_2', C2 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Y_8(s)', Y8 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
##-- Paso 8: Remoción total de la resistencia $Rc$ en serie para finalizar la síntesis.
#---------------------------------------------------------------------------------------------------------------------#

Y10, Y9 = remover_valor( Y8, sigma_zero = sigma7 )
Rc = 1/Y9
print_latex( a_equal_b_latex_s( 'Y_9(s) = \\frac{ 1 }{ Rc }', Y9 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Y_{10}(s)', Y10 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Circuito resultante con valores
#---------------------------------------------------------------------------------------------------------------------#

display( Markdown( '###' ) )
print_subtitle( '<u>Circuito resultante con valores</u>' )
display( Markdown( '###' ) )

d = dibujar_puerto_entrada( '', voltage_lbl = ( '+', '$V$', '-' ), current_lbl = '$I$' )
d, zz_lbl = dibujar_funcion_exc_abajo( d, 'Z', Z, hacia_salida = True, k_gap_width = 0.5 )
d = dibujar_elemento_serie( d, Resistor, Ra )
d = dibujar_tanque_RC_derivacion( d, R1, C1 )
d = dibujar_elemento_serie( d, Resistor, Rb )
d = dibujar_tanque_RC_derivacion( d, R2, C2 )
d = dibujar_espacio_derivacion( d )
d = dibujar_elemento_derivacion( d, Resistor, Rc )
display( d )

#---------------------------------------------------------------------------------------------------------------------#
# Out:
# ###
# #### <u>Impedancia de entrada a la red</u>
# ###
# $\displaystyle Z(s)=\frac{s^{2} + 6 s + 8}{s^{2} + 4 s + 3}$
# ###
# ###
# #### <u>Circuito propuesto con referencias</u>
# ###
# ###
# $\displaystyle Z_1(s) = Ra=\frac{8}{15}$
# ###
# $\displaystyle Z_2(s)=\frac{\left(s + 6\right) \left(7 s + 16\right)}{15 \left(s + 1\right) \left(s + 3\right)}$
# ###
# $\displaystyle Y_2(s)=\frac{15 \left(s + 1\right) \left(s + 3\right)}{\left(s + 6\right) \left(7 s + 16\right)}$
# ###
# $\displaystyle Y_3(s)=\frac{75 s}{52 \left(s + 6\right)}$
# ###
# $\displaystyle R_1=\frac{52}{75}$
# ###
# $\displaystyle C_1=\frac{25}{104}$
# ###
# $\displaystyle Y_4(s)=\frac{15 \cdot \left(17 s + 26\right)}{52 \cdot \left(7 s + 16\right)}$
# ###
# $\displaystyle Z_4(s)=\frac{52 \cdot \left(7 s + 16\right)}{15 \cdot \left(17 s + 26\right)}$
# ###
# $\displaystyle Z_5(s) = Rb=\frac{884}{1005}$
# ###
# $\displaystyle Z_6(s)=\frac{312 \cdot \left(2 s + 7\right)}{67 \cdot \left(17 s + 26\right)}$
# ###
# ...

# %% [markdown]
# ***
# ##
#
# <a id="ejercicio_2"></a>
# <img src="TS11_Ejercicio_2.png" style="margin-left:auto; margin-right:auto"/>
#
# ###### [Volver al índice](#indice)

# %% [markdown]
# ***
# ###
# #### <u>Resolución analítica</u>
# ###
#
# ###
# ##### Factorizamos y reescribimos la función excitación $Z(s)$ para expresarla estrictamente en función de sus singularidades:
# ###
#
# \begin{equation*}
# Z(s) = \frac{ s^2 + s + 1 }{ ( s^2 + 2s + 5 ) \cdot ( s + 1 ) } = \frac{ \left[ s - \left( -\frac{ 1 }{ 2 } - j\frac{ \sqrt{ 3 } }{ 2 } \right) \right] \cdot \left[ s - \left( -\frac{ 1 }{ 2 } + j\frac{ \sqrt{ 3 } }{ 2 } \right) \right] }{ \left[ s - ( - 1 - j2 ) \right] \cdot \left[ s - ( - 1 + j2 ) \right] \cdot ( s + 1 ) }
# \end{equation*}
#
# ###
# ##### Como se puede observar, la función $Z(s)$ presenta:
# ###### -Un par de ceros complejos conjugados en $s = \sigma + j\omega = -\frac{ 1 }{ 2 } \frac{ + }{ - } j\frac{ \sqrt{ 3 } }{ 2 }$,
# ###### -Un par de polos complejos conjugados en $s = \sigma + j\omega = -1 \frac{ + }{ - } j2$,
# ###### -Un polo simple en $s = \sigma + j\omega = -1$,
# ###
#
# ###
# ##### <u>Paso 1:</u> Inversión de la función $Z(s)$: se invierten los valores finitos y los ceros se reemplazan por polos y viceversa.
# ###
#
# \begin{equation*}
# Y(s) = \frac{ 1 }{ Z(s) } = \frac{ ( s^2 + 2s + 5 ) \cdot ( s + 1 ) }{ s^2 + s + 1 }
# \end{equation*}
#
# ###
# ##### <u>Paso 2:</u> Remoción total en infinito para extraer el capacitor en derivación $C_1$
# ###
#
# \begin{equation*}
# Y(s) = Y_1(s) + Y_2(s) = s \cdot k_{\infty} + Y_2(s)
# \end{equation*}
#
# ###
# ##### En la frecuencia de interés ocurre que:
# ###
#
# \begin{equation*}
# \lim_{ s -> \infty } Y_2(s) = 0
# \end{equation*}
#
# ###
# ##### Por lo tanto, podemos calcular el residuo $k_{\infty}$ de la siguiente forma:
# ###
#
# \begin{equation*}
# k_{\infty} = \lim_{ s -> \infty } \frac{ Y(s) }{ s }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_{\infty} = \lim_{ s -> \infty } \frac{ \frac{ ( s^2 + 2s + 5 ) \cdot ( s + 1 ) }{ s^2 + s + 1 } }{ s }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_{\infty} = \lim_{ s -> \infty } \frac{ s^3 + 3s^2 + 7s + 5 }{ s^3 + s^2 + s } = 1
# \end{equation*}
#
# ###
# ##### Por lo tanto, queda definido $C_1$:
# ###
#
# \begin{equation*}
# C_1 = k_{\infty} = 1
# \end{equation*}
#
# ###
# ##### Obtenemos $Y_2(s)$:
# ###
#
# \begin{equation*}
# Y_2(s) = Y(s) - s \cdot k_{\infty}
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_2(s) = \frac{ ( s^2 + 2s + 5 ) \cdot ( s + 1 ) }{ s^2 + s + 1 } - s
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_2(s) = \frac{ ( s^2 + 2s + 5 ) \cdot ( s + 1 ) - s \cdot ( s^2 + s + 1 ) }{ s^2 + s + 1 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_2(s) = \frac{ ( s^2 + 2s + 5 ) \cdot ( s + 1 ) - s^3 - s^2 - s }{ s^2 + s + 1 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_2(s) = \frac{ s^3 + 3s^2 + 7s + 5 - s^3 - s^2 - s }{ s^2 + s + 1 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_2(s) = \frac{ 2s^2 + 6s + 5 }{ s^2 + s + 1 }
# \end{equation*}
#
# ###
# ##### <u>Paso 3:</u> Remoción total en continua o en infinito para extraer la resistencia en derivación $R_1$: evaluamos $Y_2(s)$ en sus extremos para determinar donde se realizará la remoción dado que no podremos extraer más allá del mínimo valor.
# ###
#
# \begin{equation*}
# \lim_{ s -> 0 } Y_2(s) = \lim_{ s -> 0 } \frac{ 2s^2 + 6s + 5 }{ s^2 + s + 1 } = 5
# \end{equation*}
#
# ###
#
# \begin{equation*}
# \lim_{ s -> \infty } Y_2(s) = \lim_{ s -> \infty } \frac{ 2s^2 + 6s + 5 }{ s^2 + s + 1 } = 2
# \end{equation*}
#
# ###
# ##### Definimos $Y_3(s)$:
# ###
#
# \begin{equation*}
# Y_3(s) = 2
# \end{equation*}
#
# ###
# ##### De esta manera, queda definida la resistencia en derivación $R_1$:
# ###
#
# \begin{equation*}
# R_1 = \frac{ 1 }{ Y_3(s) } = \frac{ 1 }{ 2 }
# \end{equation*}
#
# ###
# ##### Obtenemos la función $Y_4(s)$:
# ###
#
# \begin{equation*}
# Y_4(s) = Y_2(s) - Y_3(s)
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ 2s^2 + 6s + 5 }{ s^2 + s + 1 } - 2
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ 2s^2 + 6s + 5 -2 \cdot ( s^2 + s + 1 ) }{ s^2 + s + 1 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ 2s^2 + 6s + 5 - 2s^2 - 2s - 2 ) }{ s^2 + s + 1 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_4(s) = \frac{ 4s + 3 }{ s^2 + s + 1 }
# \end{equation*}
#
# ###
# ##### <u>Paso 4:</u> Inversión de la función $Y_4(s)$: se invierten los valores finitos y los ceros se reemplazan por polos y viceversa.
# ###
#
# \begin{equation*}
# Z_4(s) = \frac{ 1 }{ Y_4(s) } = \frac{ s^2 + s + 1 }{ 4s + 3 }
# \end{equation*}
#
# ###
# ##### <u>Paso 5:</u> Remoción total en infinito para extraer la bobina en serie $L_1$
# ###
#
# \begin{equation*}
# Z_4(s) = Z_5(s) + Z_6(s) = s \cdot k_{{\infty}_2} + Z_6(s)
# \end{equation*}
#
# ###
# ##### En la frecuencia de interés ocurre que:
# ###
#
# \begin{equation*}
# \lim_{ s -> \infty } Z_6(s) = 0
# \end{equation*}
#
# ###
# ##### Por lo tanto, podemos calcular el residuo $k_{\infty}$ de la siguiente forma:
# ###
#
# \begin{equation*}
# k_{{\infty}_2} = \lim_{ s -> \infty } \frac{ Z_4(s) }{ s }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_{{\infty}_2} = \lim_{ s -> \infty } \frac{ \frac{ s^2 + s + 1 }{ 4s + 3 } }{ s }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_{{\infty}_2} = \lim_{ s -> \infty } \frac{ s^2 + s + 1 }{ ( 4s + 3 ) \cdot s }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_{{\infty}_2} = \lim_{ s -> \infty } \frac{ s^2 + s + 1 }{ 4s^2 + 3s } = \frac{ 1 }{ 4 }
# \end{equation*}
#
# ###
# ##### De esta manera, queda definida la bobina en serie $L_1$ y la función $Z_5(s)$:
# ###
#
# \begin{equation*}
# L_1 = k_{{\infty}_2} = \frac{ 1 }{ 4 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_5(s) = s \cdot k_{{\infty}_2} = s \cdot \frac{ 1 }{ 4 }
# \end{equation*}
#
# ###
# ##### Obtenemos la función $Y_4(s)$:
# ###
#
# \begin{equation*}
# Z_6(s) = Z_4(s) - Z_5(s)
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ s^2 + s + 1 }{ 4s + 3 } - s \cdot \frac{ 1 }{ 4 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ s^2 + s + 1 - s \cdot \frac{ 1 }{ 4 } \cdot ( 4s + 3 ) }{ 4s + 3 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ s^2 + s + 1 - s^2 - \frac{ 3 }{ 4 }s }{ 4s + 3 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_6(s) = \frac{ \frac{ 1 }{ 4 }s + 1 }{ 4s + 3 } = \frac{ 1 }{ 16 } \frac{ \left( s + \frac{ 1 }{ 4 } \right) }{ \left( s + \frac{ 3 }{ 4 } \right)}
# \end{equation*}
#
# ###
# ##### <u>Paso 6:</u> Remoción total en continua o en infinito para extraer la resistencia en serie $R_2$: evaluamos $Z_6(s)$ en sus extremos para determinar donde se realizará la remoción dado que no podremos extraer más allá del mínimo valor.
# ###
#
# \begin{equation*}
# \lim_{ s -> 0 } Z_6(s) = \lim_{ s -> 0 } \frac{ 1 }{ 16 } \frac{ \left( s + \frac{ 1 }{ 4 } \right) }{ \left( s + \frac{ 3 }{ 4 } \right)}  \frac{ 1 }{ 3 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# \lim_{ s -> \infty } Z_6(s) = \lim_{ s -> \infty } \frac{ 1 }{ 16 } \frac{ \left( s + \frac{ 1 }{ 4 } \right) }{ \left( s + \frac{ 3 }{ 4 } \right)} = \frac{ 1 }{ 16 }
# \end{equation*}
#
# ###
# ##### Definimos $Z_7(s)$:
# ###
#
# \begin{equation*}
# Z_7(s) = \frac{ 1 }{ 16 }
# \end{equation*}
#
# ###
# ##### De esta manera, queda definida la resistencia en derivación $R_1$:
# ###
#
# \begin{equation*}
# R_1 = Z_7(s) = \frac{ 1 }{ 16 }
# \end{equation*}
#
# ###
# ##### Obtenemos la función $Z_8(s)$:
# ###
#
# \begin{equation*}
# Z_8(s) = Z_6(s) - Z_7(s)
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_8(s) = \frac{ \frac{ 1 }{ 4 }s + 1 }{ 4s + 3 } - \frac{ 1 }{ 16 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_8(s) = \frac{ 16 \left( \frac{ 1 }{ 4 }s + 1 \right) - ( 4s + 3 ) }{ 16( 4s + 3 ) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_8(s) = \frac{ 4s + 16 - 4s - 3 ) }{ 16( 4s + 3 ) }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Z_8(s) = \frac{ 13 }{ 16( 4s + 3 ) } = \frac{ 13 }{ 64 } \frac{ 1 }{ \left( s + \frac{ 3 }{ 4 } \right) }
# \end{equation*}
#
# ###
# ##### <u>Paso 7:</u> Inversión de la función $Z_8(s)$: se invierten los valores finitos y los ceros se reemplazan por polos y viceversa.
# ###
#
# \begin{equation*}
# Y_8(s) = \frac{ 1 }{ Z_8(s) } = \frac{ 1 }{ \frac{ 13 }{ 64 } \frac{ 1 }{ ( s + \frac{ 3 }{ 4 } ) } } = \frac{ 64 }{ 13 } \left( s + \frac{ 3 }{ 4 } \right)
# \end{equation*}
#
# ###
# ##### <u>Paso 8:</u> Remoción total en infinito para extraer el capacitor en derivación $C_2$
# ###
#
# \begin{equation*}
# Y_8(s) = Y_9(s) + Y_{10}(s) = s \cdot k_{{\infty}_3} + Y_{10}(s)
# \end{equation*}
#
# ###
# ##### En la frecuencia de interés ocurre que:
# ###
#
# \begin{equation*}
# \lim_{ s -> \infty } Y_{10}(s) = 0
# \end{equation*}
#
# ###
# ##### Por lo tanto, podemos calcular el residuo $k_{\infty}$ de la siguiente forma:
# ###
#
# \begin{equation*}
# k_{{\infty}_3} = \lim_{ s -> \infty } \frac{ Y_8(s) }{ s }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# k_{{\infty}_3} = \lim_{ s -> \infty } \frac{ \frac{ 64 }{ 13 } \left( s + \frac{ 3 }{ 4 } \right) }{ s } = \frac{ 64 }{ 13 }
# \end{equation*}
#
# ###
# ##### De esta manera, queda definida el capacitor en derivación $C_2$ y la función $Y_9(s)$:
# ###
#
# \begin{equation*}
# C_2 = k_{{\infty}_3} = \frac{ 64 }{ 13 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_9(s) = s \cdot k_{{\infty}_3} = s \cdot \frac{ 64 }{ 13 }
# \end{equation*}
#
# ###
# ##### Obtenemos $Y_{10}(s)$:
# ###
#
# \begin{equation*}
# Y_{10}(s) = Y_8(s) - Y_9(s)
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_{10}(s) = \frac{ 64 }{ 13 } \left( s + \frac{ 3 }{ 4 } \right) - s \cdot \frac{ 64 }{ 13 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_{10}(s) = \frac{ 64 }{ 13 } \left( s + \frac{ 3 }{ 4 } - s \right) = \frac{ 64 }{ 13 } \cdot \frac{ 3 }{ 4 } = \frac{ 48 }{ 13 }
# \end{equation*}
#
# ###
# ##### <u>Paso 9:</u> Remoción total en continua o en infinito para extraer la resistencia en serie $R_3$: como se puede observar no hay necesidad de determinar donde se realizará la remoción dado que es el último componente a remover.
# ###
#
# \begin{equation*}
# Y_{10}(s) = Y_{11}(s) + Y_{12}(s)
# \end{equation*}
#
# ###
# ##### En la frecuencia de interés, por caso en infinito, ocurre que:
# ###
#
# \begin{equation*}
# \lim_{ s -> \infty } Y_{12}(s) = 0
# \end{equation*}
#
# ###
# ##### Por lo tanto, obtenemos $Y_{11}(s)$, $R_3$ e $Y_{12}(s)$:
# ###
#
# \begin{equation*}
# Y_{11}(s) = \lim_{ s -> \infty } Y_{10}(s) = \frac{ 48 }{ 13 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# R_3 = \frac{ 1 }{ Y_{11}(s) } = \frac{ 1 }{ \frac{ 48 }{ 13 } } = \frac{ 13 }{ 48 }
# \end{equation*}
#
# ###
#
# \begin{equation*}
# Y_{12}(s) = Y_{10}(s) - Y_{11}(s) = 0
# \end{equation*}
#
# ###
# ##### Dando así por finalizada la síntesis del circuito propuesto.
# ###

# %%
#---------------------------------------------------------------------------------------------------------------------#
#-- Resolución simbólica --
#---------------------------------------------------------------------------------------------------------------------#

import numpy            as     np
import sympy            as     sp
from   pytc2.remociones import remover_valor, remover_polo_infinito
from   pytc2.dibujar    import dibujar_puerto_entrada, dibujar_funcion_exc_abajo, dibujar_elemento_serie 
from   pytc2.dibujar    import dibujar_elemento_derivacion, dibujar_espacio_derivacion
from   pytc2.dibujar    import display, Resistor, Inductor, Capacitor
from   pytc2.general    import print_latex, print_subtitle, a_equal_b_latex_s
from   IPython.display  import display, Markdown, Math

#---------------------------------------------------------------------------------------------------------------------#
#-- Función de excitación Y(s)
#---------------------------------------------------------------------------------------------------------------------#

s = sp.symbols( 's', complex = True )

# Sea la siguiente función de excitación
Z = ( s**2 + s + 1 ) / ( s**2 + 2*s + 5 ) / ( s + 1 )

display( Markdown( '###' ) )
print_subtitle( '<u>Impedancia de entrada a la red</u>' )
display( Markdown( '###' ) )
print_latex( a_equal_b_latex_s( 'Z(s)', Z ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Circuito propuesto con referencias
#---------------------------------------------------------------------------------------------------------------------#

display( Markdown( '###' ) )
print_subtitle( '<u>Circuito propuesto con referencias</u>' )
display( Markdown( '###' ) )

d = dibujar_puerto_entrada( '', voltage_lbl = ('+', '$V$', '-'), current_lbl = '$I$' )
d, zz_lbl = dibujar_funcion_exc_abajo( d, 'Z', Z, hacia_salida = True, k_gap_width = 0.5 )
d = dibujar_elemento_derivacion( d, Capacitor, 'C1' )
d = dibujar_espacio_derivacion( d )
d = dibujar_elemento_derivacion( d, Resistor, 'R1')
d = dibujar_elemento_serie( d, Inductor, 'L1')
d = dibujar_elemento_serie( d, Resistor, 'R2')
d = dibujar_elemento_derivacion( d, Capacitor, 'C2' )
d = dibujar_espacio_derivacion( d )
d = dibujar_elemento_derivacion( d, Resistor, 'R3' )
display( d )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 1: Inversión de la función $Z(s)$: se invierten los valores finitos y los ceros se reemplazan por 
#-- polos y viceversa.
#---------------------------------------------------------------------------------------------------------------------#

Y = 1/Z

print_latex( a_equal_b_latex_s( 'Y(s)', Y ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 2: Remoción total en infinito para extraer el capacitor en derivación $C_1$
#---------------------------------------------------------------------------------------------------------------------# 

Y2, Y1 = remover_polo_infinito( Y )
C1 = Y1/s

print_latex( a_equal_b_latex_s( 'Y_1(s)', Y1 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'C_1', C1 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Y_2(s)', Y2 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------# 
#-- Paso 3: Remoción total en continua o en infinito para extraer la resistencia en derivación $R_1$: 
#-- evaluamos $Y_2(s)$ en sus extremos para determinar donde se realizará la remoción dado que no podremos extraer 
#-- más allá del mínimo valor.
#---------------------------------------------------------------------------------------------------------------------# 

Ginf = sp.limit( Y2, s, sp.oo )
G0 = sp.limit( Y2, s, 0 )

Y3 = np.min( ( Ginf, G0 ) )
R1 = 1/Y3
Y4 = sp.factor( sp.simplify( sp.expand( Y2 - Y3 ) ) ) 

# print( 'La función Y4 es FRP? {:s}'.format(str_si_o_no[isFRP(Y4)]) )

print_latex( a_equal_b_latex_s( 'Y_3(s)', Y3 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'R_1', R1 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Y_4(s)', Y4 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 4: Inversión de la función $Y_4(s)$: se invierten los valores finitos y los ceros se reemplazan por 
#-- polos y viceversa.
#---------------------------------------------------------------------------------------------------------------------#

Z4 = 1/Y4

print_latex( a_equal_b_latex_s( 'Z_4(s)', Z4 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 5: Remoción total en infinito para extraer la bobina en serie $L_1$
#---------------------------------------------------------------------------------------------------------------------#

Z6, Z5 = remover_polo_infinito( Z4 )
L1 = Z5/s

print_latex( a_equal_b_latex_s( 'Z_5(s)', Z5 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'L_1', L1 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Z_6(s)', Z6 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------# 
#-- Paso 6: Remoción total en continua o en infinito para extraer la resistencia en serie $R_2$: 
#-- evaluamos $Z_6(s)$ en sus extremos para determinar donde se realizará la remoción dado que no podremos extraer
#-- más allá del mínimo valor.
#---------------------------------------------------------------------------------------------------------------------# 

Rinf = sp.limit( Z6, s, sp.oo )
R0 = sp.limit( Z6, s, 0 )

Z7 = np.min( ( Rinf, R0 ) )
R2 = Z7
Z8 = sp.factor( sp.simplify( sp.expand( Z6 - Z7 ) ) ) 

#print( 'La función Z8 es FRP? {:s}'.format(str_si_o_no[isFRP(Z8)]) )

print_latex( a_equal_b_latex_s( 'Z_7(s)', Z7 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'R_2', R2 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Z_8(s)', Z8 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------# 
#-- Paso 7: Inversión de la función $Z_8(s)$: se invierten los valores finitos y los ceros se reemplazan por 
#-- polos y viceversa.
#---------------------------------------------------------------------------------------------------------------------# 

Y8 = 1/Z8

print_latex( a_equal_b_latex_s( 'Y_8(s)', Y8 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 8: Remoción total en infinito para extraer el capacitor en derivación $C_2$
#---------------------------------------------------------------------------------------------------------------------#

Y10, Y9 = remover_polo_infinito( Y8 )
C2 = Y9/s

print_latex( a_equal_b_latex_s( 'Y_9(s)', Y9 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'C_2', C2 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Y_{10}(s)', Y10 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Paso 9: Remoción total en continua o en infinito para extraer la resistencia en serie $R_3$: 
#-- como se puede observar no hay necesidad de determinar donde se realizará la remoción dado que es el último 
#-- componente a remover.
#---------------------------------------------------------------------------------------------------------------------#

Y11 = Y10
R3 = 1/Y10
Y12 = sp.factor( sp.simplify( sp.expand( Y10 - Y11 ) ) ) 

#print( 'La función Z8 es FRP? {:s}'.format(str_si_o_no[isFRP(Y12)]) )

print_latex( a_equal_b_latex_s( 'Y_{11}(s)', Y11 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'R_3', R3 ) )
display( Markdown( '###' ) )

print_latex( a_equal_b_latex_s( 'Y_{12}(s)', Y12 ) )
display( Markdown( '###' ) )

#---------------------------------------------------------------------------------------------------------------------#
#-- Circuito resultante con valores
#---------------------------------------------------------------------------------------------------------------------#

display( Markdown( '###' ) )
print_subtitle( '<u>Circuito resultante con valores</u>' )
display( Markdown( '###' ) )

d = dibujar_puerto_entrada( '', voltage_lbl = ('+', '$V$', '-'), current_lbl = '$I$' )
d, zz_lbl = dibujar_funcion_exc_abajo( d, 'Z', Z, hacia_salida = True, k_gap_width = 0.5 )
d = dibujar_elemento_derivacion( d, Capacitor, C1 )
d = dibujar_espacio_derivacion( d )
d = dibujar_elemento_derivacion( d, Resistor, R1)
d = dibujar_elemento_serie( d, Inductor, L1)
d = dibujar_elemento_serie( d, Resistor, R2)
d = dibujar_elemento_derivacion( d, Capacitor, C2 )
d = dibujar_espacio_derivacion( d )
d = dibujar_elemento_derivacion( d, Resistor, R3 )
display( d )

#---------------------------------------------------------------------------------------------------------------------#
# Out:
# ###
# #### <u>Impedancia de entrada a la red</u>
# ###
# $\displaystyle Z(s)=\frac{s^{2} + s + 1}{\left(s + 1\right) \left(s^{2} + 2 s + 5\right)}$
# ###
# ###
# #### <u>Circuito propuesto con referencias</u>
# ###
# $\displaystyle Y(s)=\frac{\left(s + 1\right) \left(s^{2} + 2 s + 5\right)}{s^{2} + s + 1}$
# ###
# $\displaystyle Y_1(s)=s$
# ###
# $\displaystyle C_1=1$
# ###
# $\displaystyle Y_2(s)=\frac{2 s^{2} + 6 s + 5}{s^{2} + s + 1}$
# ###
# $\displaystyle Y_3(s)=2$
# ###
# $\displaystyle R_1=\frac{1}{2}$
# ###
# $\displaystyle Y_4(s)=\frac{4 s + 3}{s^{2} + s + 1}$
# ###
# $\displaystyle Z_4(s)=\frac{s^{2} + s + 1}{4 s + 3}$
# ###
# $\displaystyle Z_5(s)=\frac{s}{4}$
# ###
# $\displaystyle L_1=\frac{1}{4}$
# ###
# $\displaystyle Z_6(s)=\frac{s + 4}{4 \cdot \left(4 s + 3\right)}$
# ###
# $\displaystyle Z_7(s)=\frac{1}{16}$
# ###
# $\displaystyle R_2=\frac{1}{16}$
# ###
# $\displaystyle Z_8(s)=\frac{13}{16 \cdot \left(4 s + 3\right)}$
# ###
# ...

# %% [markdown]
# ***
#
# ##
# <a id="bibliografia"></a>
# ### <span style="text-decoration: underline;">Bibliografía sugerida:</span>
# ##
#
# ###### Araujo, [*"Análisis y Síntesis de Redes Lineales I"*](https://drive.google.com/file/d/1LMrdMPUB0KsCBBYTuvpXFqYCaDdjYmyM/view?usp=sharing), Cap. 4: Métodos de síntesis de dipolos pasivos
#
# ###### Kuo, [*"Network Analysis and Synthesis"*](https://drive.google.com/file/d/1WZEsKhywwb5SJqR7fEId6gJI8eIU8dB-/view?usp=sharing), Cap. 11: Synthesis of One-Port Networks With Two Kinds Of Elements
#
# ###### Cogollos Borrás, [*"Fundamentos de la Teoría de Filtros"*](https://drive.google.com/file/d/1g4pgNS1m9dF43ZyR6LdkE-HAntfswhwh/view?usp=sharing)
#
# ##
# ### <span style="text-decoration: underline;">Otros documentos consultados:</span>
# ##
#
# ###### Llamedo Soria, [*"Síntesis de funciones de excitación RC-RL"*](https://pytc2.readthedocs.io/en/latest/funciones_excitacion_disipativas.html)
#
# ###### Llamedo Soria, [*"Síntesis de algunas funciones RLC"*](https://pytc2.readthedocs.io/en/latest/funciones_excitacion_RLC.html)
#
# ##
# ### <span style="text-decoration: underline;">Lista de reproducción:</span>
# ##
#
# ###### Llamedo Soria, [*"Clase 12 - Síntesis de Imitancias Disipativas. Teoría de Circuitos 2 - UTN FRBA - Ingeniería Electrónica"*](https://www.youtube.com/playlist?list=PLlD2eDv5CIe8r2gsVISGU6NbvlVwVdgrn)
#
# ###
#
# ###### [Volver al índice](#indice)
#
# ***

# %% [markdown]
# ##### © Copyright 2023, Moharos, David Santiago. Revision 1.0.0.
# ***

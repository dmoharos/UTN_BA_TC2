# %% [markdown]
# <img src="./TS3_Logo_UTN.svg" align="right" width="150" />
#
# ##
#
# ***
#
# ## (950431) Teoría de Circuitos II
#
# ***
#
# #### Profesor: Mariano Llamedo Soria  <llamedom@frba.utn.edu.ar>
# #### Jefe de TPs: César Fuoco  <cfuoco@frba.utn.edu.ar>
# #### Ayudante de TPs: Israel Pavelek <pavel@frba.utn.edu.ar>
#
# ####
# ***

# %% [markdown]
# # Trabajo Semanal # 3
#
# #### Autor: *Moharos, David Santiago* <dmoharos@frba.utn.edu.ar>
#
# ####
#
# ***

# %% [markdown]
# ####
#
# ### A partir de la siguiente plantilla, sabiendo que:
#
# ####

# %% [markdown]
# <img src="./TS3_Plantilla.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# ***
# ***
# ####
#
# ### 1. Obtener la transferencia para máxima planicidad en la banda de paso utilizando los conceptos de partes de función. Recordar que: $\begin{equation}|T(jω)|2=T(jω)⋅T(−jω)=T(s)⋅T(−s)|s=jω\end{equation}$
#
# ####
#
# ***
# ***
#
# ####

# %%
from IPython.display import IFrame
IFrame("./TS3_Análisis_Ppal_01.pdf", width= 1000, height= 3450)
# Out:
#         <iframe
#             width="1000"
#             height="3450"
#             src="./TS3_Análisis_Ppal_01.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ***
# ***
# ####
#
# ### 2. Obtener el diagrama de polos y ceros, y un bosquejo de la respuesta en frecuencia.
#
# ####
#
# ***
# ***
#
# ####

# %%
from IPython.display import IFrame
IFrame("./TS3_Análisis_Ppal_02.pdf", width= 1000, height= 1150)
# Out:
#         <iframe
#             width="1000"
#             height="1150"
#             src="./TS3_Análisis_Ppal_02.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ####
# ***
# #### Simulación de transferencia (módulo y fase), diagrama de polos y ceros y retardo de grupo
# ***
# ####

# %%
##### !/usr/bin/env python3
# -*- coding: utf-8 -*-

#------------------------------------------------------------------------------------------------------------------------------------#
#                                               -- Inicialización de librerías --                                                    #
#------------------------------------------------------------------------------------------------------------------------------------#

from scipy.signal import TransferFunction
from scipy import signal as sig
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

#------------------------------------------------------------------------------------------------------------------------------------#
#                                         -- Configuración para visualización de gráficos --                                         #
#------------------------------------------------------------------------------------------------------------------------------------#

mpl.rcParams['figure.figsize'] = (10,10)
fig_sz_x= 14
fig_sz_y= 13
fig_dpi= 80 # dpi
fig_font_size= 10
plt.rcParams.update({'font.size':fig_font_size})

#------------------------------------------------------------------------------------------------------------------------------------#
#                                                -- Declaración de variables --                                                      #
#------------------------------------------------------------------------------------------------------------------------------------#


#------------------------------------------------------------------------------------------------------------------------------------#
#                                                       -- Gráficos --                                                               #
#                       -- Transferencia (módulo y fase), diagramas de polos y ceros y retardo de grupo --                           #
#------------------------------------------------------------------------------------------------------------------------------------#

num= [1.9653]
den= [1, 2.5051, 3.1379, 1.9653]
my_tf = TransferFunction(num, den)

plt.close('all')

bodePlot(my_tf, fig_id=1)
pzmap(my_tf, fig_id=2)
GroupDelay(my_tf, fig_id=3)


#------------------------------------------------------------------------------------------------------------------------------------#
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# ***
# ***
# ####
#
# ### 3. Implementar el circuito normalizado con estructuras pasivas separadas mediante buffers.
#
# ####
#
# ***
# ***
#
# ####

# %%
from IPython.display import IFrame
IFrame("./TS3_Análisis_Ppal_03.pdf", width= 1000, height= 2250)
# Out:
#         <iframe
#             width="1000"
#             height="2250"
#             src="./TS3_Análisis_Ppal_03.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ####
# ***
# #### Simulación numérica NORMALIZADA de transferencia (módulo y fase), diagrama de polos y ceros y retardo de grupo
# ***
# ####

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

#------------------------------------------------------------------------------------------------------------------------------------#
#                                               -- Inicialización de librerías --                                                    #
#------------------------------------------------------------------------------------------------------------------------------------#

from scipy.signal import TransferFunction
from scipy import signal as sig
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

#------------------------------------------------------------------------------------------------------------------------------------#
#                                         -- Configuración para visualización de gráficos --                                         #
#------------------------------------------------------------------------------------------------------------------------------------#

mpl.rcParams['figure.figsize'] = (10,10)
fig_sz_x= 14
fig_sz_y= 13
fig_dpi= 80 # dpi
fig_font_size= 10
plt.rcParams.update({'font.size':fig_font_size})

#------------------------------------------------------------------------------------------------------------------------------------#
#                                                -- Declaración de variables --                                                      #
#------------------------------------------------------------------------------------------------------------------------------------#

Q= 1
ω_0= 1.2526

R1_n= 1
C1_n= 0.7983
L_n= 0.7983

R2_n= 1
C2_n= 0.7983

#------------------------------------------------------------------------------------------------------------------------------------#
#                                                       -- Gráficos --                                                               #
#                       -- Transferencia (módulo y fase), diagramas de polos y ceros y retardo de grupo --                           #
#------------------------------------------------------------------------------------------------------------------------------------#

my_tf = TransferFunction( [ω_0**3], [1, 2*ω_0, 2*ω_0**2, ω_0**3] )
qq= np.sqrt(Q)
plt.close('all')

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq) )
pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq))
GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq))
    
#------------------------------------------------------------------------------------------------------------------------------------#
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# ####
# ***
# #### Simulación circuital NORMALIZADA en LTSpice de la respuesta en frecuencia (módulo y fase) de la transferencia $\begin{equation}T(s)= \frac{Vout}{Vin}\end{equation}$:
# ***
# ####

# %% [markdown]
# <img src="./TS3_Circuito_Red_Pasiva_Normalizada.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# <img src="./TS3_Circuito_Red_Pasiva_Normalizada_Respuesta_Modulo.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# <img src="./TS3_Circuito_Red_Pasiva_Normalizada_Respuesta_Fase.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# ***
# ***
# #### >>> Hacer algún comentario de los valores de frecuencia normalizada, que cumple con la plantilla, etc...
# ***
# ***

# %% [markdown]
# ***
# ***
# ####
#
# ### 4. Obtenga el circuito que cumpla con la plantilla requerida si dispone de capacitores de 100nf.
#
# ####
#
# ***
# ***
#
# ####

# %%
from IPython.display import IFrame
IFrame("./TS3_Análisis_Ppal_04.pdf", width= 1000, height= 1500)
# Out:
#         <iframe
#             width="1000"
#             height="1500"
#             src="./TS3_Análisis_Ppal_04.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ####
# ***
# #### Simulación numérica DESNORMALIZADA de transferencia (módulo y fase), diagrama de polos y ceros y retardo de grupo
# ***
# ####

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

#------------------------------------------------------------------------------------------------------------------------------------#
#                                               -- Inicialización de librerías --                                                    #
#------------------------------------------------------------------------------------------------------------------------------------#

from scipy.signal import TransferFunction
from scipy import signal as sig
from math import pi
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

#------------------------------------------------------------------------------------------------------------------------------------#
#                                         -- Configuración para visualización de gráficos --                                         #
#------------------------------------------------------------------------------------------------------------------------------------#

mpl.rcParams['figure.figsize'] = (10,10)
fig_sz_x= 14
fig_sz_y= 13
fig_dpi= 80 # dpi
fig_font_size= 10
plt.rcParams.update({'font.size':fig_font_size})

#------------------------------------------------------------------------------------------------------------------------------------#
#                                                -- Declaración de variables --                                                      #
#------------------------------------------------------------------------------------------------------------------------------------#

fp= 1500
ω_p= 2*pi*fp
Ω_ω= ω_p

ω_0_n= 1.2526
ω_0= ω_0_n*Ω_ω
Q= 1

R1_n= 1
L_n= 0.7983
C1_n= 0.7983

C1= 100e-9

#C1= C1_n/(Ω_ω*Ω_z)
Ω_z= C1_n/(Ω_ω*C1)
R1= Ω_z
L= (L_n*Ω_z)/Ω_ω

#------------------------------------------------------------------------------------------------------------------------------------#
#                                                       -- Gráficos --                                                               #
#                       -- Transferencia (módulo y fase), diagramas de polos y ceros y retardo de grupo --                           #
#------------------------------------------------------------------------------------------------------------------------------------#

my_tf = TransferFunction( [ω_0**3], [1, 2*ω_0, 2*ω_0**2, ω_0**3] )
qq= np.sqrt(Q)
plt.close('all')

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq) )
pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq))
GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq))
    
#------------------------------------------------------------------------------------------------------------------------------------#
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# ####
# ***
# #### Simulación circuital DESNORMALIZADA en LTSpice de la respuesta en frecuencia (módulo y fase) de la transferencia $\begin{equation}T(s)= \frac{Vout}{Vin}\end{equation}$:
# ***
# ####

# %% [markdown]
# <img src="./TS3_Circuito_Red_Pasiva_Desnormalizada.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# <img src="./TS3_Circuito_Red_Pasiva_Desnormalizada_Respuesta_Modulo.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# <img src="./TS3_Circuito_Red_Pasiva_Desnormalizada_Respuesta_Fase.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# ***
# ***
# ####
#
# ### 5. Proponga una red que se comporte igual a la hallada en 4) pero con resistores, capacitores y opamps.
#
# ####
#
# ***
# ***
#
# ####

# %%
from IPython.display import IFrame
IFrame("./TS3_Análisis_Ppal_05.pdf", width= 1000, height= 1600)
# Out:
#         <iframe
#             width="1000"
#             height="1600"
#             src="./TS3_Análisis_Ppal_05.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
